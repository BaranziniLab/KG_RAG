# %%
import pandas as pd
import numpy as np
import re
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt

# %%
def get_auc(test_question):
    label_encoder = LabelEncoder()
    test_question['label_encoded'] = label_encoder.fit_transform(test_question['label'])
    test_question['extracted_answer_encoded'] = label_encoder.transform(test_question['extracted_answer'])
    auc_score = roc_auc_score(test_question['label_encoded'], test_question['extracted_answer_encoded'])
    return auc_score

def extract_answer(text):
    pattern = r"(True|False|Don't know)"
    matches = re.findall(pattern, text)
    return matches

# %%
PROMPT_RESPONSE_PATH = "../../../data/analysis_results/Llama_2_13b_chat_hf_prompt_based_response.csv"
RAG_RESPONSE_PATH = "../../../data/analysis_results/Llama_2_13b_chat_hf_node_retrieval_rag_based_response.csv"

# %%
response_transform = {
    "True" : True,
    "False" : False,
    "Don't know" : "Don't know"
}

# %%
prompt_response_df = pd.read_csv(PROMPT_RESPONSE_PATH)

prompt_response_df.loc[:, 'extracted_answer'] = prompt_response_df['llm_answer'].apply(extract_answer)
prompt_response_df.loc[:, "answer_count"] = prompt_response_df.extracted_answer.apply(lambda x:len(x))

prompt_response_df_multiple_answers = prompt_response_df[prompt_response_df.answer_count > 1]
prompt_response_df_single_answer = prompt_response_df.drop(prompt_response_df_multiple_answers.index)
prompt_response_df_single_answer.drop("answer_count", axis=1, inplace=True)


prompt_response_df_multiple_answers_ = []
for index, row in prompt_response_df_multiple_answers.iterrows():
    if row["extracted_answer"][0] == row["extracted_answer"][1]:
        prompt_response_df_multiple_answers_.append((row["question"], row["label"], row["llm_answer"], row["extracted_answer"][0]))
    else:
        prompt_response_df_multiple_answers_.append((row["question"], row["label"], row["llm_answer"], "Don't know"))

prompt_response_df_multiple_answers_ = pd.DataFrame(prompt_response_df_multiple_answers_, columns=["question", "label", "llm_answer", "extracted_answer"])

prompt_response_df_final = pd.concat([prompt_response_df_single_answer, prompt_response_df_multiple_answers_], ignore_index=True)
prompt_response_df_final = prompt_response_df_final.explode("extracted_answer")
prompt_response_df_final['extracted_answer'].fillna("Don't know", inplace=True)

prompt_response_df_final.extracted_answer = prompt_response_df_final.extracted_answer.apply(lambda x:response_transform[x])
prompt_response_df_certain = prompt_response_df_final[prompt_response_df_final.extracted_answer != "Don't know"]
prompt_response_df_uncertain = prompt_response_df_final[prompt_response_df_final.extracted_answer == "Don't know"]

label_encoder = LabelEncoder()
prompt_response_df_certain['label_encoded'] = label_encoder.fit_transform(prompt_response_df_certain['label'])
prompt_response_df_certain['extracted_answer_encoded'] = label_encoder.transform(prompt_response_df_certain['extracted_answer'])
prompt_response_df_correct_response = prompt_response_df_certain[prompt_response_df_certain.label_encoded == prompt_response_df_certain.extracted_answer_encoded]
prompt_response_df_incorrect_response = prompt_response_df_certain[prompt_response_df_certain.label_encoded != prompt_response_df_certain.extracted_answer_encoded]

prompt_response_df_certain.head()
# Out:
# /var/folders/p1/h56gxdhs5vgb0ztp7h4z606h0000gn/T/ipykernel_14215/1090471572.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prompt_response_df_certain['label_encoded'] = label_encoder.fit_transform(prompt_response_df_certain['label'])
# /var/folders/p1/h56gxdhs5vgb0ztp7h4z606h0000gn/T/ipykernel_14215/1090471572.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prompt_response_df_certain['extracted_answer_encoded'] = label_encoder.transform(prompt_response_df_certain['extracted_answer'])
#                                             question  label  \
# 0  enhanced S-cone syndrome is not a vitreoretina...  False
# 1               metronidazole treats crohn's disease   True
# 2  KLEEFSTRA SYNDROME 1 is not associated with Ge...  False
# 3  STARGARDT DISEASE 1 (disorder) is not associat...  False
# 4  Juvenile polyposis syndrome associates Gene SMAD4   True
#
#                                           llm_answer extracted_answer  \
# 0    {\n"answer": "False"\n}\n\nEnhanced S-cone s...            False
# 1    {\n"answer": "False"\n}\n\nMetronidazole is ...            False
# 2                          {\n  "answer": "False"\n}            False
# 3                          {\n  "answer": "False"\n}            False
# 4                             {\n"answer": "True"\n}             True
#
#    label_encoded  extracted_answer_encoded
# 0              0                         0
# 1              1                         0
# 2              0                         0
# 3              0                         0
# 4              1                         1

# %%
rag_response_df = pd.read_csv(RAG_RESPONSE_PATH)

rag_response_df.loc[:, 'extracted_answer'] = rag_response_df['llm_answer'].apply(extract_answer)
rag_response_df.loc[:, "answer_count"] = rag_response_df.extracted_answer.apply(lambda x:len(x))

rag_response_df_multiple_answers = rag_response_df[rag_response_df.answer_count > 1]
rag_response_df_single_answer = rag_response_df.drop(rag_response_df_multiple_answers.index)
rag_response_df_single_answer.drop("answer_count", axis=1, inplace=True)


rag_response_df_multiple_answers_ = []
for index, row in rag_response_df_multiple_answers.iterrows():
    if row["extracted_answer"][0] == row["extracted_answer"][1]:
        rag_response_df_multiple_answers_.append((row["question"], row["label"], row["llm_answer"], row["extracted_answer"][0]))
    else:
        rag_response_df_multiple_answers_.append((row["question"], row["label"], row["llm_answer"], "Don't know"))

rag_response_df_multiple_answers_ = pd.DataFrame(rag_response_df_multiple_answers_, columns=["question", "label", "llm_answer", "extracted_answer"])

rag_response_df_final = pd.concat([rag_response_df_single_answer, rag_response_df_multiple_answers_], ignore_index=True)
rag_response_df_final = rag_response_df_final.explode("extracted_answer")
rag_response_df_final['extracted_answer'].fillna("Don't know", inplace=True)

rag_response_df_final.extracted_answer = rag_response_df_final.extracted_answer.apply(lambda x:response_transform[x])
rag_response_df_certain = rag_response_df_final[rag_response_df_final.extracted_answer != "Don't know"]
rag_response_df_uncertain = rag_response_df_final[rag_response_df_final.extracted_answer == "Don't know"]

label_encoder = LabelEncoder()
rag_response_df_certain['label_encoded'] = label_encoder.fit_transform(rag_response_df_certain['label'])
rag_response_df_certain['extracted_answer_encoded'] = label_encoder.transform(rag_response_df_certain['extracted_answer'])
rag_response_df_correct_response = rag_response_df_certain[rag_response_df_certain.label_encoded == rag_response_df_certain.extracted_answer_encoded]
rag_response_df_incorrect_response = rag_response_df_certain[rag_response_df_certain.label_encoded != rag_response_df_certain.extracted_answer_encoded]

rag_response_df_certain.head()
# Out:
# /var/folders/p1/h56gxdhs5vgb0ztp7h4z606h0000gn/T/ipykernel_14215/3915019513.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rag_response_df_certain['label_encoded'] = label_encoder.fit_transform(rag_response_df_certain['label'])
# /var/folders/p1/h56gxdhs5vgb0ztp7h4z606h0000gn/T/ipykernel_14215/3915019513.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rag_response_df_certain['extracted_answer_encoded'] = label_encoder.transform(rag_response_df_certain['extracted_answer'])
#                                             question  label  \
# 0  enhanced S-cone syndrome is not a vitreoretina...  False
# 1               metronidazole treats crohn's disease   True
# 2  KLEEFSTRA SYNDROME 1 is not associated with Ge...  False
# 3  STARGARDT DISEASE 1 (disorder) is not associat...  False
# 4  Juvenile polyposis syndrome associates Gene SMAD4   True
#
#                   llm_answer extracted_answer  label_encoded  \
# 0     {\n"answer": "True"\n}             True              0
# 1     {\n"answer": "True"\n}             True              1
# 2    {\n"answer": "False"\n}            False              0
# 3    {\n"answer": "False"\n}            False              0
# 4     {\n"answer": "True"\n}             True              1
#
#    extracted_answer_encoded
# 0                         1
# 1                         1
# 2                         0
# 3                         0
# 4                         1

# %%
rag_response_df_uncertain[rag_response_df_uncertain.question.isin(prompt_response_df_correct_response.question)]
# Out:
#                                               question  label  \
# 265  Lecithin Acyltransferase Deficiency associates...   True
# 365  Variant rs2476601 associates Rheumatoid Arthritis   True
# 425        Septo-Optic Dysplasia associates Gene HESX1   True
# 443  Hidrotic Ectodermal Dysplasia associates Gene ...   True
#
#                                             llm_answer extracted_answer
# 265                       {\n"answer": "Don't know"\n}       Don't know
# 365                       {\n"answer": "Don't know"\n}       Don't know
# 425    Based on the information provided in the con...       Don't know
# 443    Based on the information provided, the answe...       Don't know

# %%
rag_response_df_incorrect_response[rag_response_df_incorrect_response.question.isin(prompt_response_df_correct_response.question)]
# Out:
#                                               question  label  \
# 0    enhanced S-cone syndrome is not a vitreoretina...  False
# 37   Crigler Najjar syndrome, type 1 associates Gen...   True
# 73                      emicizumab treats hemophilia a   True
# 91   vitelliform macular dystrophy is not a macular...  False
# 114  Bloom syndrome is not a autosomal recessive di...  False
# 123  Ichthyosis linearis circumflexa associates Gen...   True
# 137             Okihiro Syndrome associates Gene SALL4   True
# 138          Aniridia is not associated with Gene PAX6  False
# 148    Johanson-Blizzard syndrome associates Gene UBR1   True
# 164           alpha-galactosidase treats fabry disease   True
# 166                     Piebaldism associates Gene KIT   True
# 178         Papillorenal syndrome associates Gene PAX2   True
# 240  Chronic Infantile Neurological, Cutaneous, and...   True
# 287  congenital contractural arachnodactyly is not ...  False
# 294  Hyperkalemic periodic paralysis is not associa...  False
# 316                    factor viia treats hemophilia a   True
# 321  alpha-d-galactosidase enzyme treats fabry disease   True
# 332  Brugada Syndrome (disorder) associates Gene SCN5A   True
# 336  Hepatolenticular Degeneration associates Gene ...   True
# 358  XERODERMA PIGMENTOSUM, COMPLEMENTATION GROUP E...   True
# 362  prothrombin complex concentrates treats hemoph...   True
# 374  Hereditary liability to pressure palsies assoc...   True
# 397            Lobstein Disease associates Gene COL1A1   True
# 416     Poikiloderma of Kindler associates Gene FERMT1   True
# 426      Maple Syrup Urine Disease associates Gene DBT   True
# 449  Infantile Neuroaxonal Dystrophy associates Gen...   True
# 462            LEOPARD Syndrome associates Gene PTPN11   True
# 488  Otospondylomegaepiphyseal dysplasia associates...   True
# 494  nusinersen treats hmn (hereditary motor neurop...   True
# 540            Shwachman syndrome associates Gene SBDS   True
# 546             Huntington Disease associates Gene HTT   True
# 562  Cryptophthalmos syndrome is not associated wit...  False
# 580  Bietti crystalline corneoretinal dystrophy is ...  False
# 592  Cardio-facio-cutaneous syndrome associates Gen...   True
# 608               Lafora Disease associates Gene EPM2A   True
#
#                                             llm_answer extracted_answer  \
# 0                               {\n"answer": "True"\n}             True
# 37                             {\n"answer": "False"\n}            False
# 73     Sure! Based on the information provided, her...            False
# 91                              {\n"answer": "True"\n}             True
# 114                             {\n"answer": "True"\n}             True
# 123    {\n"answer": "False"\n}\n\nIchthyosis linear...            False
# 137    Based on the information provided, the answe...            False
# 138    Sure, I'd be happy to help!\n\nAfter reviewi...             True
# 148                          {\n  "answer": "False"\n}            False
# 164    {\n  "answer": "False"\n}\n\n alpha-galactos...            False
# 166    Sure, I can help you with that!\n\nAfter rev...            False
# 178                            {\n"answer": "False"\n}            False
# 240                            {\n"answer": "False"\n}            False
# 287                             {\n"answer": "True"\n}             True
# 294    Sure, I'd be happy to help!\n\nContext:\n\nH...             True
# 316    Based on the information provided, the answe...            False
# 321    {\n  "answer": "False"\n}\n\nExplanation:\n\...            False
# 332                            {\n"answer": "False"\n}            False
# 336    As an expert biomedical researcher, I have r...            False
# 358    Sure, I can help you with that!\n\nBased on ...            False
# 362    Sure, I'd be happy to help! Based on the inf...            False
# 374    Sure, I'd be happy to help!\n\nBased on the ...            False
# 397                          {\n  "answer": "False"\n}            False
# 416    Based on the context provided, the answer is...            False
# 426                            {\n"answer": "False"\n}            False
# 449    {\n"answer": "False"\n}\n\nInfantile Neuroax...            False
# 462    Sure, I'd be happy to help!\n\nBased on the ...            False
# 488    Sure! I'd be happy to help.\n\nBased on the ...            False
# 494    As an expert biomedical researcher, I have r...            False
# 540                            {\n"answer": "False"\n}            False
# 546    Sure, I'd be happy to help!\n\nAfter reviewi...            False
# 562                             {\n"answer": "True"\n}             True
# 580                             {\n"answer": "True"\n}             True
# 592    Sure, I can help you with that!\n\nAfter rev...            False
# 608    Sure, I'd be happy to help!\n\nAfter reviewi...            False
#
#      label_encoded  extracted_answer_encoded
# 0                0                         1
# 37               1                         0
# 73               1                         0
# 91               0                         1
# 114              0                         1
# 123              1                         0
# 137              1                         0
# 138              0                         1
# 148              1                         0
# 164              1                         0
# 166              1                         0
# 178              1                         0
# 240              1                         0
# 287              0                         1
# 294              0                         1
# 316              1                         0
# 321              1                         0
# 332              1                         0
# 336              1                         0
# 358              1                         0
# 362              1                         0
# 374              1                         0
# 397              1                         0
# 416              1                         0
# 426              1                         0
# 449              1                         0
# 462              1                         0
# 488              1                         0
# 494              1                         0
# 540              1                         0
# 546              1                         0
# 562              0                         1
# 580              0                         1
# 592              1                         0
# 608              1                         0

# %%
prompt_response_df_incorrect_response.shape
# Out:
# (60, 6)

# %%
rag_response_df_incorrect_response[rag_response_df_incorrect_response.question.isin(prompt_response_df_correct_response.question)].question.values
# Out:
# array(['enhanced S-cone syndrome is not a vitreoretinal degeneration',
#        'Crigler Najjar syndrome, type 1 associates Gene UGT1A1',
#        'emicizumab treats hemophilia a',
#        'vitelliform macular dystrophy is not a macular degeneration',
#        'Bloom syndrome is not a autosomal recessive disease',
#        'Ichthyosis linearis circumflexa associates Gene SPINK5',
#        'Okihiro Syndrome associates Gene SALL4',
#        'Aniridia is not associated with Gene PAX6',
#        'Johanson-Blizzard syndrome associates Gene UBR1',
#        'alpha-galactosidase treats fabry disease',
#        'Piebaldism associates Gene KIT',
#        'Papillorenal syndrome associates Gene PAX2',
#        'Chronic Infantile Neurological, Cutaneous, and Articular Syndrome associates Gene NLRP3',
#        'congenital contractural arachnodactyly is not a congenital nervous system disorder',
#        'Hyperkalemic periodic paralysis is not associated with Gene SCN4A',
#        'factor viia treats hemophilia a',
#        'alpha-d-galactosidase enzyme treats fabry disease',
#        'Brugada Syndrome (disorder) associates Gene SCN5A',
#        'Hepatolenticular Degeneration associates Gene ATP7B',
#        'XERODERMA PIGMENTOSUM, COMPLEMENTATION GROUP E associates Gene DDB2',
#        'prothrombin complex concentrates treats hemophilia b',
#        'Hereditary liability to pressure palsies associates Gene PMP22',
#        'Lobstein Disease associates Gene COL1A1',
#        'Poikiloderma of Kindler associates Gene FERMT1',
#        'Maple Syrup Urine Disease associates Gene DBT',
#        'Infantile Neuroaxonal Dystrophy associates Gene PLA2G6',
#        'LEOPARD Syndrome associates Gene PTPN11',
#        'Otospondylomegaepiphyseal dysplasia associates Gene COL11A2',
#        'nusinersen treats hmn (hereditary motor neuropathy) proximal type i',
#        'Shwachman syndrome associates Gene SBDS',
#        'Huntington Disease associates Gene HTT',
#        'Cryptophthalmos syndrome is not associated with Gene FRAS1',
#        'Bietti crystalline corneoretinal dystrophy is not a familial flecked retinopathy',
#        'Cardio-facio-cutaneous syndrome associates Gene BRAF',
#        'Lafora Disease associates Gene EPM2A'], dtype=object)

# %%
rag_response_df_incorrect_response[rag_response_df_incorrect_response.question.isin(prompt_response_df_correct_response.question)].llm_answer.values
# Out:
# array(['  {\n"answer": "True"\n}', '  {\n"answer": "False"\n}',
#        '  Sure! Based on the information provided, here is my answer in the requested JSON format:\n\n{\n"answer": "False"\n}\n\nEmicizumab does not treat hemophilia A, as it is indicated for the treatment of hemophilia B.',
#        '  {\n"answer": "True"\n}', '  {\n"answer": "True"\n}',
#        '  {\n"answer": "False"\n}\n\nIchthyosis linearis circumflexa does not associate with the Gene SPINK5.',
#        '  Based on the information provided, the answer is:\n\n{\n"answer": "False"\n}\n\nOkihiro Syndrome is not associated with the gene SALL4.',
#        '  Sure, I\'d be happy to help!\n\nAfter reviewing the context, I can confirm that Aniridia is associated with the PAX6 gene. Therefore, the answer is:\n\n{\n"answer": "True"\n}\n\nPAX6 is a critical gene that plays a crucial role in the development of the eye, and mutations in this gene have been linked to Aniridia, a condition characterized by a partial or complete absence of the iris.',
#        '  {\n  "answer": "False"\n}',
#        '  {\n  "answer": "False"\n}\n\n alpha-galactosidase is an enzyme that is deficient in Fabry disease, but it is not a treatment for the disease. Fabry disease is a lysosomal storage disorder caused by a deficiency of the enzyme alpha-galactosidase A, which leads to the accumulation of a substance called globotriaosylsphingosine (Lewandowsky et al., 2015). Treatment for Fabry disease typically involves enzyme replacement therapy with recombinant alpha-galactosidase A, which can help to reduce the accumulation of globotriaosylsphingosine and improve symptoms such as pain, fatigue, and kidney damage (Harmatz et al., 2016).',
#        '  Sure, I can help you with that!\n\nAfter reviewing the context you provided, I can answer your question as follows:\n\n{\n"answer": "False"\n}\n\nPiebaldism does not associate with Gene KIT, as it is an autosomal dominant genetic disorder caused by mutations in the KIT gene.',
#        '  {\n"answer": "False"\n}', '  {\n"answer": "False"\n}',
#        '  {\n"answer": "True"\n}',
#        "  Sure, I'd be happy to help!\n\nContext:\n\nHyperkalemic periodic paralysis (HPP) is a rare genetic disorder characterized by recurrent episodes of muscle weakness and paralysis, triggered by high potassium levels in the blood. The disorder is caused by mutations in the SCN4A gene, which encodes the voltage-gated potassium channel subunit alpha.\n\nQuestion: Is Hyperkalemic periodic paralysis associated with the SCN4A gene?\n\nAnswer: True. Hyperkalemic periodic paralysis is associated with mutations in the SCN4A gene.",
#        '  Based on the information provided, the answer is:\n\n{\n"answer": "False"\n}\n\nFactor VII deficiency and hemophilia A are two different conditions. Factor VII deficiency is a blood coagulation disorder that can cause symptoms such as reduced factor VII activity, abnormality of coagulation, and bleeding. Hemophilia A, on the other hand, is a genetic disorder that affects the blood\'s ability to clot, causing bleeding and joint pain. While both conditions can cause bleeding, they have different underlying causes and are treated with different medications. Therefore, factor VIIA does not treat hemophilia A.',
#        '  {\n  "answer": "False"\n}\n\nExplanation:\n\nAlpha-d-galactosidase is an enzyme that is deficient in Fabry disease, but it is not the enzyme that treats Fabry disease. Fabry disease is a lysosomal storage disorder caused by a deficiency of the enzyme alpha-galactosidase A, which is essential for the breakdown of certain fatty substances in the body.\n\nWhile alpha-d-galactosidase is a different enzyme, it is also involved in the breakdown of galactose, a sugar molecule that is found in many foods. However, it is not the enzyme that treats Fabry disease. The treatment for Fabry disease typically involves enzyme replacement therapy with alpha-galactosidase A, which can help to reduce the symptoms of the disease and improve the quality of life for affected individuals.',
#        '  {\n"answer": "False"\n}',
#        '  As an expert biomedical researcher, I have read the context provided and I can answer the question.\n\nHepatolenticular Degeneration does not associate with Gene ATP7B.\n\nTherefore, the answer is:\n\n{\n"answer": "False"\n}',
#        '  Sure, I can help you with that!\n\nBased on the information provided, XERODERMA PIGMENTOSUM, COMPLEMENTATION GROUP E does not associate with Gene DDB2.\n\nTherefore, the answer is:\n\n{\n"answer": "False"\n}',
#        '  Sure, I\'d be happy to help! Based on the information provided, the answer to the question is:\n\n{\n"answer": "False"\n}\n\nProthrombin complex concentrates are not used to treat hemophilia B. Hemophilia B is a bleeding disorder caused by a deficiency of factor IX, and prothrombin complex concentrates do not contain factor IX. Instead, factor IX concentrates are used to treat hemophilia B.',
#        '  Sure, I\'d be happy to help!\n\nBased on the context provided, the answer is:\n\n{\n"answer": "False"\n}\n\nThe context mentions several genes associated with autosomal genetic diseases, but there is no mention of Gene PMP22 being associated with hereditary liability to pressure palsies.',
#        '  {\n  "answer": "False"\n}',
#        '  Based on the context provided, the answer is:\n\n{\n"answer": "False"\n}\n\nPoikiloderma of Kindler is a genetic disorder that is associated with mutations in the POMT1 gene, but not with the FERMT1 gene.',
#        '  {\n"answer": "False"\n}',
#        '  {\n"answer": "False"\n}\n\nInfantile Neuroaxonal Dystrophy is a rare genetic disorder that is not associated with the gene PLA2G6. The disease is caused by mutations in the POMT1 gene, which encodes a protein involved in the synthesis of dystroglycan, a critical component of the extracellular matrix in muscle cells. The PLA2G6 gene, on the other hand, encodes a phospholipase A2 enzyme that is involved in the regulation of lipid metabolism and has not been linked to Infantile Neuroaxonal Dystrophy.',
#        '  Sure, I\'d be happy to help!\n\nBased on the context you provided, the answer is:\n\n{\n"answer": "False"\n}\n\nLEOPARD syndrome is not associated with the Gene PTPN11.',
#        '  Sure! I\'d be happy to help.\n\nBased on the context you provided, the answer is:\n\n{\n"answer": "False"\n}\n\nOtospondylomegaepiphyseal dysplasia does not associate with Gene COL11A2. The disease ontology identifier for otospondylomegaepiphyseal dysplasia is DOID:0080026, which is autosomal recessive, and does not associate with Gene COL11A2.',
#        '  As an expert biomedical researcher, I have read the context provided and can answer your question.\n\nNusinersen does not treat hereditary motor neuropathy (HMN) proximal type I. The disease ontology identifier for HMN proximal type I is DOID:0111198, and nusinersen is not indicated for the treatment of this condition.\n\nTherefore, my answer is:\n\n{\n"answer": "False"\n}',
#        '  {\n"answer": "False"\n}',
#        '  Sure, I\'d be happy to help!\n\nAfter reviewing the context you provided, I can confidently say that:\n\n{\n"answer": "False"\n}\n\nHuntington Disease does not associate with the Gene HTT. Instead, the genes associated with hereditary ataxia are ATM, PNPT1, and TDP2.',
#        '  {\n"answer": "True"\n}', '  {\n"answer": "True"\n}',
#        '  Sure, I can help you with that!\n\nAfter reviewing the context you provided, I can answer your question as follows:\n\n{\n"answer": "False"\n}\n\nCardio-facio-cutaneous syndrome does not associate with Gene BRAF, based on the information provided in the context.',
#        '  Sure, I\'d be happy to help!\n\nAfter reviewing the context, I can confirm that Lafora Disease does not associate with the EPM2A gene. The correct answer is "False".\n\nHere\'s the JSON format you requested:\n\n{\n"answer": "False"\n}'],
#       dtype=object)

# %%
rag_response_df_uncertain[rag_response_df_uncertain.question.isin(prompt_response_df_correct_response.question)].question.values
# Out:
# array(['KLEEFSTRA SYNDROME 1 is not associated with Gene EHMT1',
#        'Meleda Disease is not associated with Gene SLURP1',
#        'Limb-girdle muscular dystrophy type 2H associates Gene TRIM32',
#        'Arthrogryposis, renal dysfunction, and cholestasis 1 associates Gene VPS33B',
#        'X-linked hydrocephalus syndrome associates Gene L1CAM',
#        'Cardiomyopathy, Familial Idiopathic associates Gene LMNA',
#        'piebaldism is a autosomal dominant disease',
#        'Senter syndrome associates Gene GJB2',
#        'MEGALENCEPHALIC LEUKOENCEPHALOPATHY WITH SUBCORTICAL CYSTS associates Gene MLC1',
#        'Shprintzen syndrome associates Gene TBX1',
#        'HEMOCHROMATOSIS, TYPE 4 associates Gene SLC40A1',
#        'Ichthyosis linearis circumflexa associates Gene SPINK5',
#        'Congenital chloride diarrhea associates Gene SLC26A3',
#        'Congenital Nonbullous Ichthyosiform Erythroderma associates Gene TGM1',
#        'Carney complex is a autosomal dominant disease',
#        'MASA SYNDROME (disorder) is not associated with Gene L1CAM',
#        'Progressive pseudorheumatoid dysplasia associates Gene CCN6',
#        'Papillorenal syndrome associates Gene PAX2',
#        'Pfeiffer syndrome is a acrocephalopolysyndactyly',
#        'Diabetes Mellitus, Non-Insulin-Dependent associates Gene PAX4',
#        'Johanson-Blizzard syndrome is a congenital nervous system disorder',
#        'KUFOR-RAKEB SYNDROME associates Gene ATP13A2',
#        "6-mercaptopurine treats crohn's disease",
#        'Wolcott-Rallison syndrome is a syndromic disease',
#        'FUNDUS DYSTROPHY, PSEUDOINFLAMMATORY, OF SORSBY associates Gene TIMP3',
#        'Chronic Infantile Neurological, Cutaneous, and Articular Syndrome associates Gene NLRP3',
#        'Omenn Syndrome associates Gene RAG2',
#        'Ataxia with vitamin E deficiency associates Gene TTPA',
#        'Craniofrontonasal dysplasia is not associated with Gene EFNB1',
#        'Schimke immunoosseous dysplasia associates Gene SMARCAL1',
#        'Variant rs2066845 is not associated with Crohn Disease',
#        'Variant rs2476601 associates Diabetes Mellitus, Insulin-Dependent',
#        'Nephroblastomatosis, fetal ascites, macrosomia and Wilms tumor is not associated with Gene DIS3L2',
#        'Pitt-Hopkins syndrome is a syndromic disease',
#        'Bernard-Soulier Syndrome associates Gene GP1BB',
#        'protein-tyrosine kinase inhibitor treats gastrointestinal stromal tumors',
#        'Biotinidase Deficiency is not associated with Gene BTD',
#        'BIETTI CRYSTALLINE CORNEORETINAL DYSTROPHY is not associated with Gene CYP4V2',
#        'Variant rs2476601 associates Rheumatoid Arthritis',
#        'Porphyria, Erythropoietic associates Gene UROS',
#        'Central Diabetes Insipidus associates Gene AVP',
#        'CHARCOT-MARIE-TOOTH DISEASE, TYPE 4C associates Gene SH3TC2',
#        'Sandhoff disease is a eye degenerative disorder',
#        'Lhermitte-Duclos disease associates Gene PTEN',
#        'Congenital Generalized Lipodystrophy Type 2 associates Gene BSCL2',
#        'Leukodystrophy, Metachromatic associates Gene ARSA',
#        'Coffin-Siris syndrome is a syndromic disease',
#        'Septo-Optic Dysplasia associates Gene HESX1',
#        'Hidrotic Ectodermal Dysplasia associates Gene GJB6',
#        'Leukemia, Myelocytic, Acute is not associated with Gene FLT3',
#        'Schnyder crystalline corneal dystrophy associates Gene UBIAD1',
#        'Chondrodysplasia punctata, X-linked dominant type is not associated with Gene EBP',
#        'Kleefstra syndrome 1 is a Kleefstra syndrome',
#        'SPINAL MUSCULAR ATROPHY WITH RESPIRATORY DISTRESS 1 associates Gene IGHMBP2',
#        'Xeroderma pigmentosum, group F associates Gene ERCC4',
#        'Creatine deficiency, X-linked associates Gene SLC6A8',
#        'Epidermolysis bullosa with pyloric atresia is not associated with Gene ITGB4',
#        'Mosaic variegated aneuploidy syndrome 1 associates Gene BUB1B',
#        'TIBIAL MUSCULAR DYSTROPHY, TARDIVE associates Gene TTN',
#        'protein-tyrosine kinase inhibitor treats sarcoma',
#        'Cryptophthalmos syndrome is not associated with Gene FRAS1',
#        'Oculo-dento-digital syndrome is not associated with Gene GJA1',
#        'Timothy syndrome associates Gene CACNA1C',
#        'Johanson-Blizzard syndrome associates Gene UBR1',
#        'argipressin treats central diabetes insipidus',
#        'Hyperkalemic periodic paralysis is not associated with Gene SCN4A',
#        'Jervell-Lange Nielsen Syndrome is not associated with Gene KCNQ1',
#        'Argininosuccinic Aciduria associates Gene ASL',
#        'CHARCOT-MARIE-TOOTH DISEASE, TYPE 4J associates Gene FIG4',
#        'Achondrogenesis type 2 is not associated with Gene COL2A1'],
#       dtype=object)
