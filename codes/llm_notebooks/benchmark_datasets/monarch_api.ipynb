# %%
import requests
import pandas as pd
from tqdm import tqdm
from utility import *

# %%
DISEASE_GENE_URI = "https://api.monarchinitiative.org/api/bioentity/disease/{}/genes"
DISEASE_VARIANT_URI = "https://api.monarchinitiative.org/api/bioentity/disease/{}/variants"

disease_path = "../../../data/benchmark_datasets/monarch/gwas_diseases.csv"

params = {}
params["rows"] = 2
params["direct"] = "true"
params["direct_taxon"] = "true"

# %%
disease_df = pd.read_csv(disease_path)
disease_df.columns = ["disease_id", "disease_name"]
disease_df.disease_id = disease_df.disease_id.apply(lambda x:x.split('"')[1])
disease_df
# Out:
#        disease_id                         disease_name
# 0    DOID:0080630  "B-lymphoblastic leukemia/lymphoma"
# 1       DOID:8893                          "psoriasis"
# 2       DOID:1712              "aortic valve stenosis"
# 3      DOID:13189                               "gout"
# 4       DOID:5418           "schizoaffective disorder"
# ..            ...                                  ...
# 249     DOID:1380                 "endometrial cancer"
# 250     DOID:6039                     "uveal melanoma"
# 251    DOID:10538              "gastric fundus cancer"
# 252  DOID:0111910              "spermatogenic failure"
# 253  DOID:0080745                       "polymyositis"
#
# [254 rows x 2 columns]

# %%
def get_api_resp(URI, params=None):
    if params:
        return requests.get(URI, params=params)
    else:
        return requests.get(URI)
    
def get_association(URI, disease_id, params, object_attribute="label"):
    URI_ = URI.format(disease_id)
    resp = get_api_resp(URI_, params=params)
    if resp.status_code == 200:
        response = resp.json()
        associations = response["associations"]
        object_list = []
        for item in associations:
            object_list.append(item["object"][object_attribute])
        df = pd.DataFrame(object_list, columns=["object"])
        df["subject"] = disease_id
        return df
    else:
        return None

# %%
edge_df_list = []

for index, row in tqdm(disease_df.iterrows()):
    edge_df_list.append(get_association(DISEASE_GENE_URI, row["disease_id"], params))

edge_df = pd.concat(edge_df_list, ignore_index=True)
edge_df = pd.merge(edge_df, disease_df, left_on="subject", right_on="disease_id").drop(["subject", "disease_id"], axis=1)
edge_df.disease_name = edge_df.disease_name.apply(lambda x:x.split('"')[1])

data_mcq_disease_gene = create_mcq(edge_df, "disease_name", "object", "Gene", "is associated with")
# Out:
# 254it [01:46,  2.38it/s]

# %%
edge_df_list_2 = []

for index, row in tqdm(disease_df.iterrows()):
    edge_df_list_2.append(get_association(DISEASE_VARIANT_URI, row["disease_id"], params, object_attribute="id"))

edge_df_2 = pd.concat(edge_df_list_2, ignore_index=True)
edge_df_2 = pd.merge(edge_df_2, disease_df, left_on="subject", right_on="disease_id").drop(["subject", "disease_id"], axis=1)
edge_df_2.disease_name = edge_df_2.disease_name.apply(lambda x:x.split('"')[1])
edge_df_2.object = edge_df_2.object.apply(lambda x:x.split("dbSNP:")[-1])
# Out:
# 254it [01:42,  2.47it/s]

# %%
data_mcq_disease_variant = create_mcq(edge_df_2, "disease_name", "object", "Variant", "is associated with")

# %%
data_mcq_monarch = pd.concat([data_mcq_disease_gene, data_mcq_disease_variant], ignore_index=True)

# %%
data_mcq_monarch.to_csv("../../../data/benchmark_datasets/test_questions_two_hop_mcq_from_monarch.csv", index=False, header=True)

# %%
data_mcq_disease_variant
# Out:
#                                             disease_pair  \
# 1705              (breast carcinoma, male breast cancer)
# 2674   (abdominal aortic aneurysm, thoracic aortic an...
# 2994                         (colon carcinoma, melanoma)
# 3092         (colon carcinoma, hepatocellular carcinoma)
# 3106                   (colon carcinoma, lung carcinoma)
# 3147      (Kawasaki disease, inflammatory bowel disease)
# 5839      (inflammatory bowel disease, Kawasaki disease)
# 6968   (triple-receptor negative breast cancer, uteri...
# 7774                    (vitiligo, rheumatoid arthritis)
# 8744              (male breast cancer, breast carcinoma)
# 11105        (autoimmune hepatitis, collagenous colitis)
# 11167  (autoimmune hepatitis, cutaneous lupus erythem...
# 15260  (head and neck squamous cell carcinoma, gliobl...
# 15331  (head and neck squamous cell carcinoma, esopha...
# 15974    (Barrett's esophagus, esophagus adenocarcinoma)
# 16089  (glioblastoma, head and neck squamous cell car...
# 16163               (glioblastoma, esophageal carcinoma)
# 16405          (ankylosing spondylitis, Crohn's disease)
# 16469                   (rheumatoid arthritis, vitiligo)
# 17109        (collagenous colitis, autoimmune hepatitis)
# 17199  (collagenous colitis, cutaneous lupus erythema...
# 17278                        (melanoma, colon carcinoma)
# 17458                         (melanoma, lung carcinoma)
# 19019  (age related macular degeneration, Kuhnt-Juniu...
# 19227  (Kuhnt-Junius degeneration, age related macula...
# 20516               (duodenal ulcer, atrophic gastritis)
# 20591            (duodenal ulcer, gastric fundus cancer)
# 21873  (uterine fibroid, triple-receptor negative bre...
# 23004       (prostate carcinoma, large intestine cancer)
# 24871     (squamous cell carcinoma, androgenic alopecia)
# 25079     (androgenic alopecia, squamous cell carcinoma)
# 25349          (sclerosing cholangitis, Crohn's disease)
# 26110       (large intestine cancer, prostate carcinoma)
# 27762               (atrophic gastritis, duodenal ulcer)
# 27871        (atrophic gastritis, gastric fundus cancer)
# 30005  (cutaneous lupus erythematosus, autoimmune hep...
# 30034  (cutaneous lupus erythematosus, collagenous co...
# 30857  (esophageal carcinoma, head and neck squamous ...
# 30861               (esophageal carcinoma, glioblastoma)
# 30977  (esophageal carcinoma, lung squamous cell carc...
# 31157  (childhood type dermatomyositis, dermatomyositis)
# 32015  (central nervous system cancer, lung adenocarc...
# 34677  (dermatomyositis, childhood type dermatomyositis)
# 34812    (esophagus adenocarcinoma, Barrett's esophagus)
# 37244  (thoracic aortic aneurysm, abdominal aortic an...
# 37662        (hepatocellular carcinoma, colon carcinoma)
# 37934          (Crohn's disease, ankylosing spondylitis)
# 37977          (Crohn's disease, sclerosing cholangitis)
# 40089  (lung adenocarcinoma, central nervous system c...
# 40500  (lung squamous cell carcinoma, esophageal carc...
# 40574                  (lung carcinoma, colon carcinoma)
# 40643                         (lung carcinoma, melanoma)
# 43362            (gastric fundus cancer, duodenal ulcer)
# 43397        (gastric fundus cancer, atrophic gastritis)
#
#                 correct_node  \
# 1705               rs3803662
# 2674                rs595244
# 2994    ClinVarVariant:13961
# 3092    ClinVarVariant:13652
# 3106    ClinVarVariant:13961
# 3147               rs1801274
# 5839               rs1801274
# 6968              rs78378222
# 7774               rs2476601
# 8744               rs3803662
# 11105              rs2187668
# 11167              rs2187668
# 15260  ClinVarVariant:376659
# 15331  ClinVarVariant:376659
# 15974              rs3784262
# 16089  ClinVarVariant:376659
# 16163  ClinVarVariant:376659
# 16405             rs11209026
# 16469              rs2476601
# 17109              rs2187668
# 17199              rs2187668
# 17278   ClinVarVariant:13961
# 17458   ClinVarVariant:13961
# 19019             rs10490924
# 19227             rs10490924
# 20516              rs2294008
# 20591              rs2294008
# 21873             rs78378222
# 23004              rs6983267
# 24871             rs12203592
# 25079             rs12203592
# 25349              rs3197999
# 26110              rs6983267
# 27762              rs2294008
# 27871              rs2294008
# 30005              rs2187668
# 30034              rs2187668
# 30857  ClinVarVariant:376659
# 30861  ClinVarVariant:376659
# 30977   ClinVarVariant:45251
# 31157              rs4921293
# 32015              rs2736100
# 34677              rs4921293
# 34812              rs3784262
# 37244               rs595244
# 37662   ClinVarVariant:13652
# 37934             rs11209026
# 37977              rs3197999
# 40089              rs2736100
# 40500   ClinVarVariant:45251
# 40574   ClinVarVariant:13961
# 40643   ClinVarVariant:13961
# 43362              rs2294008
# 43397              rs2294008
#
#                                         negative_samples  \
# 1705          rs17045031, rs170020, rs2115691, rs4728142
# 2674           rs170884, rs59325236, rs219780, rs4459895
# 2994          rs2391769, rs11209026, rs452932, rs2857595
# 3092          rs2129979, rs10490924, rs167769, rs2143571
# 3106   MGI:3817496, MGI:2450162, ClinVarVariant:14163...
# 3147          MGI:2655190, rs670142, rs2736100, rs170020
# 5839   ClinVarVariant:376659, rs78378222, rs16948876,...
# 6968   rs4543123, ClinVarVariant:18061, rs11015915, r...
# 7774   rs3784262, rs9427573, rs72755233, FlyBase:FBal...
# 8744   ClinVarVariant:18061, rs10124723, rs10127000, ...
# 11105          rs284491, rs3862469, rs1537377, rs8176719
# 11167           rs3803662, rs999944, rs752590, rs6969780
# 15260     MGI:4430747, rs10455657, rs2736100, rs76972608
# 15331      MGI:5524274, rs12203592, rs2736100, rs6079395
# 15974      rs4704825, rs12203592, MGI:5428331, rs1642764
# 16089       rs2473355, rs11209026, rs7426056, rs73018258
# 16163  rs4921293, ClinVarVariant:375224, rs170884, rs...
# 16405        rs2359536, rs2072499, MGI:4357686, rs595244
# 16469  ClinVarVariant:7820, rs4789400, rs17398575, rs...
# 17109  rs7383917, rs17045031, rs2071754, ClinVarVaria...
# 17199       rs139606545, rs6675307, rs3787184, rs9272143
# 17278      rs10455657, rs7579899, rs6986444, rs112082427
# 17458      rs10908366, rs12792820, rs1801274, rs11712066
# 19019        rs4624820, rs4263037, rs10228350, rs2294008
# 19227  rs3129939, ClinVarVariant:43659, rs4804217, rs...
# 20516  rs2231142, ClinVarVariant:376659, ClinVarVaria...
# 20591  rs6903608, rs4939827, ClinVarVariant:7820, Fly...
# 21873        rs11174202, rs3129939, rs1642764, rs9272143
# 23004  ClinVarVariant:13272, rs2391769, rs56404467, r...
# 24871     rs11846409, MGI:3721992, rs977145, MGI:3829386
# 25079  rs11209026, rs2349775, rs201026476, ClinVarVar...
# 25349        rs2476601, rs2797501, rs2856830, rs17711053
# 26110        rs2359536, rs7426056, rs1937450, rs12203592
# 27762          rs4957796, rs988958, rs6457327, rs4617927
# 27871    rs4459895, MGI:5547617, rs11015915, MGI:3033883
# 30005  MGI:4357686, ClinVarVariant:140608, rs4543123,...
# 30034  rs201026476, rs9275260, rs10483727, ClinVarVar...
# 30857      rs11209026, MGI:1855969, rs3197999, rs2473355
# 30861         rs2736100, rs167479, rs9648346, rs10908366
# 30977       rs4957796, rs2294008, MGI:1856318, rs2294008
# 31157  ClinVarVariant:14011, rs887829, rs12203592, rs...
# 32015  ClinVarVariant:13852, rs11031006, rs115879499,...
# 34677  ClinVarVariant:375878, ClinVarVariant:48031, r...
# 34812  rs6675307, ClinVarVariant:13652, MGI:3829386, ...
# 37244        rs4939827, rs8014252, rs2071754, rs73018258
# 37662         rs1025128, rs887829, rs67490716, rs3862469
# 37934  rs284491, rs3914132, rs9270986, ClinVarVariant...
# 37977  ClinVarVariant:13652, rs12151790, rs2230199, M...
# 40089  rs711830, ClinVarVariant:16613, rs7579899, Cli...
# 40500  rs670142, rs2187668, ClinVarVariant:217851, rs...
# 40574        rs61882743, rs167479, rs1709393, rs17810546
# 40643         rs170884, rs3784262, rs1025128, rs57602752
# 43362      rs17810546, rs3803662, rs4789400, MGI:5428331
# 43397           rs752590, rs2230199, rs1127354, rs229527
#
#                                     disease_1  \
# 1705                         breast carcinoma
# 2674                abdominal aortic aneurysm
# 2994                          colon carcinoma
# 3092                          colon carcinoma
# 3106                          colon carcinoma
# 3147                         Kawasaki disease
# 5839               inflammatory bowel disease
# 6968   triple-receptor negative breast cancer
# 7774                                 vitiligo
# 8744                       male breast cancer
# 11105                    autoimmune hepatitis
# 11167                    autoimmune hepatitis
# 15260   head and neck squamous cell carcinoma
# 15331   head and neck squamous cell carcinoma
# 15974                     Barrett's esophagus
# 16089                            glioblastoma
# 16163                            glioblastoma
# 16405                  ankylosing spondylitis
# 16469                    rheumatoid arthritis
# 17109                     collagenous colitis
# 17199                     collagenous colitis
# 17278                                melanoma
# 17458                                melanoma
# 19019        age related macular degeneration
# 19227               Kuhnt-Junius degeneration
# 20516                          duodenal ulcer
# 20591                          duodenal ulcer
# 21873                         uterine fibroid
# 23004                      prostate carcinoma
# 24871                 squamous cell carcinoma
# 25079                     androgenic alopecia
# 25349                  sclerosing cholangitis
# 26110                  large intestine cancer
# 27762                      atrophic gastritis
# 27871                      atrophic gastritis
# 30005           cutaneous lupus erythematosus
# 30034           cutaneous lupus erythematosus
# 30857                    esophageal carcinoma
# 30861                    esophageal carcinoma
# 30977                    esophageal carcinoma
# 31157          childhood type dermatomyositis
# 32015           central nervous system cancer
# 34677                         dermatomyositis
# 34812                esophagus adenocarcinoma
# 37244                thoracic aortic aneurysm
# 37662                hepatocellular carcinoma
# 37934                         Crohn's disease
# 37977                         Crohn's disease
# 40089                     lung adenocarcinoma
# 40500            lung squamous cell carcinoma
# 40574                          lung carcinoma
# 40643                          lung carcinoma
# 43362                   gastric fundus cancer
# 43397                   gastric fundus cancer
#
#                                     disease_2  \
# 1705                       male breast cancer
# 2674                 thoracic aortic aneurysm
# 2994                                 melanoma
# 3092                 hepatocellular carcinoma
# 3106                           lung carcinoma
# 3147               inflammatory bowel disease
# 5839                         Kawasaki disease
# 6968                          uterine fibroid
# 7774                     rheumatoid arthritis
# 8744                         breast carcinoma
# 11105                     collagenous colitis
# 11167           cutaneous lupus erythematosus
# 15260                            glioblastoma
# 15331                    esophageal carcinoma
# 15974                esophagus adenocarcinoma
# 16089   head and neck squamous cell carcinoma
# 16163                    esophageal carcinoma
# 16405                         Crohn's disease
# 16469                                vitiligo
# 17109                    autoimmune hepatitis
# 17199           cutaneous lupus erythematosus
# 17278                         colon carcinoma
# 17458                          lung carcinoma
# 19019               Kuhnt-Junius degeneration
# 19227        age related macular degeneration
# 20516                      atrophic gastritis
# 20591                   gastric fundus cancer
# 21873  triple-receptor negative breast cancer
# 23004                  large intestine cancer
# 24871                     androgenic alopecia
# 25079                 squamous cell carcinoma
# 25349                         Crohn's disease
# 26110                      prostate carcinoma
# 27762                          duodenal ulcer
# 27871                   gastric fundus cancer
# 30005                    autoimmune hepatitis
# 30034                     collagenous colitis
# 30857   head and neck squamous cell carcinoma
# 30861                            glioblastoma
# 30977            lung squamous cell carcinoma
# 31157                         dermatomyositis
# 32015                     lung adenocarcinoma
# 34677          childhood type dermatomyositis
# 34812                     Barrett's esophagus
# 37244               abdominal aortic aneurysm
# 37662                         colon carcinoma
# 37934                  ankylosing spondylitis
# 37977                  sclerosing cholangitis
# 40089           central nervous system cancer
# 40500                    esophageal carcinoma
# 40574                         colon carcinoma
# 40643                                melanoma
# 43362                          duodenal ulcer
# 43397                      atrophic gastritis
#
#                                                     text
# 1705   Out of the given list, which Variant is associ...
# 2674   Out of the given list, which Variant is associ...
# 2994   Out of the given list, which Variant is associ...
# 3092   Out of the given list, which Variant is associ...
# 3106   Out of the given list, which Variant is associ...
# 3147   Out of the given list, which Variant is associ...
# 5839   Out of the given list, which Variant is associ...
# 6968   Out of the given list, which Variant is associ...
# 7774   Out of the given list, which Variant is associ...
# 8744   Out of the given list, which Variant is associ...
# 11105  Out of the given list, which Variant is associ...
# 11167  Out of the given list, which Variant is associ...
# 15260  Out of the given list, which Variant is associ...
# 15331  Out of the given list, which Variant is associ...
# 15974  Out of the given list, which Variant is associ...
# 16089  Out of the given list, which Variant is associ...
# 16163  Out of the given list, which Variant is associ...
# 16405  Out of the given list, which Variant is associ...
# 16469  Out of the given list, which Variant is associ...
# 17109  Out of the given list, which Variant is associ...
# 17199  Out of the given list, which Variant is associ...
# 17278  Out of the given list, which Variant is associ...
# 17458  Out of the given list, which Variant is associ...
# 19019  Out of the given list, which Variant is associ...
# 19227  Out of the given list, which Variant is associ...
# 20516  Out of the given list, which Variant is associ...
# 20591  Out of the given list, which Variant is associ...
# 21873  Out of the given list, which Variant is associ...
# 23004  Out of the given list, which Variant is associ...
# 24871  Out of the given list, which Variant is associ...
# 25079  Out of the given list, which Variant is associ...
# 25349  Out of the given list, which Variant is associ...
# 26110  Out of the given list, which Variant is associ...
# 27762  Out of the given list, which Variant is associ...
# 27871  Out of the given list, which Variant is associ...
# 30005  Out of the given list, which Variant is associ...
# 30034  Out of the given list, which Variant is associ...
# 30857  Out of the given list, which Variant is associ...
# 30861  Out of the given list, which Variant is associ...
# 30977  Out of the given list, which Variant is associ...
# 31157  Out of the given list, which Variant is associ...
# 32015  Out of the given list, which Variant is associ...
# 34677  Out of the given list, which Variant is associ...
# 34812  Out of the given list, which Variant is associ...
# 37244  Out of the given list, which Variant is associ...
# 37662  Out of the given list, which Variant is associ...
# 37934  Out of the given list, which Variant is associ...
# 37977  Out of the given list, which Variant is associ...
# 40089  Out of the given list, which Variant is associ...
# 40500  Out of the given list, which Variant is associ...
# 40574  Out of the given list, which Variant is associ...
# 40643  Out of the given list, which Variant is associ...
# 43362  Out of the given list, which Variant is associ...
# 43397  Out of the given list, which Variant is associ...
