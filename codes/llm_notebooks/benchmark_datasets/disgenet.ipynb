# %%
import pandas as pd

# %%
DISEASE_DATA_PATH = "../../../data/benchmark_datasets/disgenet/disease_associations.tsv"
GENE_DATA_PATH = "../../../data/benchmark_datasets/disgenet/gene_associations.tsv"

# %%
data_disease = pd.read_csv(DISEASE_DATA_PATH, sep="\t")
data_gene = pd.read_csv(GENE_DATA_PATH, sep="\t")

# %%
data_disease
# Out:
#       diseaseId                                        diseaseName  \
# 0      C0000727                                     Abdomen, Acute
# 1      C0000729                                   Abdominal Cramps
# 2      C0000731                                  Abdomen distended
# 3      C0000734                                     Abdominal mass
# 4      C0000735                                Abdominal Neoplasms
# ...         ...                                                ...
# 30165  C4755314             Autosomal recessive cutis laxa type 2B
# 30166  C4757950                   Isolated ATP synthase deficiency
# 30167  C4757951  Desmoplastic infantile astrocytoma and ganglio...
# 30168  C4759295                     Non-metastatic prostate cancer
# 30169  C4759434  PF-ILD-progressive fibrosing interstitial lung...
#
#       diseaseType diseaseClass  diseaseSemanticType  NofGenes  NofPmids
# 0       phenotype          C23      Sign or Symptom         2         2
# ...

# %%
data_gene
# Out:
#           geneId geneSymbol    DSI    DPI           PLI protein_class_name  \
# 0              1       A1BG  0.700  0.538  4.991700e-09           Receptor
# 1              2        A2M  0.529  0.769  4.522900e-11   Enzyme modulator
# 2              3      A2MP1    NaN    NaN           NaN                NaN
# 3              9       NAT1  0.536  0.846  1.929400e-14             Enzyme
# 4             10       NAT2  0.451  0.885  3.274400e-06             Enzyme
# ...          ...        ...    ...    ...           ...                ...
# 21666  115482722      H3P33  0.736  0.346           NaN                NaN
# 21667  115482723      H3P40  0.506  0.846           NaN                NaN
# 21668  115561815   LNC-LBCS  0.890  0.077           NaN                NaN
# 21669  115804232     CEROX1    NaN    NaN           NaN                NaN
# 21670  115891964   MIR223HG  0.861  0.077           NaN                NaN
#
#       protein_class  NofDiseases  NofPmids
# ...

# %%
data_disease[data_disease.diseaseName.str.contains("Parkinson")]
# Out:
#       diseaseId                                        diseaseName  \
# 2346   C0030567                                  Parkinson Disease
# 2347   C0030568                Parkinson Disease, Postencephalitic
# 2348   C0030569                        Secondary Parkinson Disease
# 3202   C0043202                     Wolff-Parkinson-White Syndrome
# 5191   C0236960                Dementia due to Parkinson's disease
# 5546   C0242422                             Parkinsonian Disorders
# 8708   C0349081                    Dementia in Parkinson's disease
# 10728  C0586392                                Parkinsonian tremor
# 11659  C0751414              Parkinson Disease, Secondary Vascular
# 11660  C0751415                       Atherosclerotic Parkinsonism
# 11912  C0752097      Autosomal Dominant Juvenile Parkinson Disease
# 11913  C0752098                    Autosomal Dominant Parkinsonism
# 11914  C0752100                   Autosomal Recessive Parkinsonism
# ...
