# %%
import requests
import pandas as pd
import sqlite3
from tqdm import tqdm
from math import ceil

# %%
DB_PATH = "../../../data/benchmark_datasets/disgenet/disgenet_2020.db"


API_URL = "https://biothings.ncats.io/semmeddb/query"

REFERENCE_PREDICATE = "TREATS"
RETURN_RESULT_COUNT = 1000
PMID_THRESH = 25

# %%
# %%time

conn = sqlite3.connect(DB_PATH)
c = conn.cursor()


table_name = "diseaseAttributes"
c.execute("SELECT * FROM {}".format(table_name))
rows = c.fetchall()
disease_df = pd.DataFrame(rows, columns=["diseaseNID", "diseaseId", "diseaseName", "type"])

table_name = "geneAttributes"
c.execute("SELECT * FROM {}".format(table_name))
rows = c.fetchall()
gene_df = pd.DataFrame(rows, columns=["geneNID", "geneId", "geneName", "geneDescription", "pLI", "DSI", "DPI"])


table_name = "geneDiseaseNetwork"
c.execute("SELECT * FROM {}".format(table_name))
rows = c.fetchall()
disease_gene_df = pd.DataFrame(rows, columns=["NID", "diseaseNID", "geneNID", "source", "association", "associationType", "sentence", "pmid", "score", "EL", "EI", "year"])
# Selecting association with maximum score
disease_gene_df_selected  = disease_gene_df[disease_gene_df.score == 1]
disease_gene_df_selected_1 = pd.merge(disease_gene_df_selected, disease_df, on="diseaseNID")
disease_gene_df_selected_2 = pd.merge(disease_gene_df_selected_1, gene_df, on="geneNID")
# Out:
# CPU times: user 8.67 s, sys: 1.48 s, total: 10.2 s
# Wall time: 10.7 s

# %%
disease_ids = disease_gene_df_selected_2.diseaseId.unique()

# %%
# %%time

result_list = []
for sel_disease_id in tqdm(disease_ids):
    params = {}
    params["q"] = "subject.umls:{}".format(sel_disease_id)
    params["size"] = RETURN_RESULT_COUNT

    response = requests.get(API_URL, params=params)
    result = response.json()
    hits = result["hits"]
    for item in hits:
        try:
            if item["object"]["semantic_type_name"] == "Disease or Syndrome":
                result_list.append((item["subject"]["name"], item["predicate"], item["object"]["name"], item["pmid_count"], item["subject"]["semantic_type_name"], item["object"]["semantic_type_name"]))
        except:
            continue
# Out:
# 100%|█████████████████████████████████████████| 353/353 [03:54<00:00,  1.51it/s]
# CPU times: user 21.4 s, sys: 1.47 s, total: 22.9 s
# Wall time: 3min 54s

# %%
result_df = pd.DataFrame(result_list, columns=["subject", "predicate", "object", "pmid_count", "subject_semantic_type", "object_semantic_type"])
result_df = result_df.sort_values(by="pmid_count", ascending=False)
result_df
# Out:
#                            subject          predicate  \
# 921             Huntington Disease                ISA
# 3847                       Obesity                ISA
# 2682               Cystic Fibrosis                ISA
# 3448                 Fabry Disease                ISA
# 3818                       Obesity        PREDISPOSES
# ...                            ...                ...
# 3584  Muscular Dystrophy, Duchenne                ISA
# 3581  Muscular Dystrophy, Duchenne      COEXISTS_WITH
# 3580  Muscular Dystrophy, Duchenne  NEG_COEXISTS_WITH
# 3579  Muscular Dystrophy, Duchenne      COEXISTS_WITH
# 9334     Infantile myofibromatosis             CAUSES
#
#                              object  pmid_count subject_semantic_type  \
# 921     Neurodegenerative Disorders        2136   Disease or Syndrome
# 3847             Metabolic Diseases        1243   Disease or Syndrome
# 2682            Hereditary Diseases         867   Disease or Syndrome
# 3448     Lysosomal Storage Diseases         573   Disease or Syndrome
# 3818           Hypertensive disease         566   Disease or Syndrome
# ...                             ...         ...                   ...
# 3584                 Fetal Diseases           1   Disease or Syndrome
# 3581  Congenital muscular dystrophy           1   Disease or Syndrome
# 3580  Amyotrophic Lateral Sclerosis           1   Disease or Syndrome
# 3579    Autoimmune hemolytic anemia           1   Disease or Syndrome
# 9334         Intestinal Obstruction           1    Neoplastic Process
#
#      object_semantic_type
# 921   Disease or Syndrome
# 3847  Disease or Syndrome
# 2682  Disease or Syndrome
# 3448  Disease or Syndrome
# 3818  Disease or Syndrome
# ...                   ...
# 3584  Disease or Syndrome
# 3581  Disease or Syndrome
# 3580  Disease or Syndrome
# 3579  Disease or Syndrome
# 9334  Disease or Syndrome
#
# [9335 rows x 6 columns]

# %%
result_df.predicate.unique()
# Out:
# array(['AFFECTS', 'ISA', 'COEXISTS_WITH', 'CAUSES', 'NEG_COEXISTS_WITH',
#        'MANIFESTATION_OF', 'PRECEDES', 'NEG_CAUSES', 'COMPLICATES',
#        'NEG_MANIFESTATION_OF', 'NEG_ISA', 'NEG_AFFECTS', 'PREDISPOSES',
#        'AUGMENTS', 'ASSOCIATED_WITH', 'NEG_PREDISPOSES', 'NEG_AUGMENTS',
#        'NEG_COMPLICATES', 'NEG_PRECEDES', 'compared_with'], dtype=object)

# %%
result_df_ = result_df[result_df.pmid_count > 25]
result_df_[result_df_.predicate=="ISA"]
# Out:
#                                    subject predicate  \
# 921                     Huntington Disease       ISA
# 3847                               Obesity       ISA
# 2682                       Cystic Fibrosis       ISA
# 3448                         Fabry Disease       ISA
# 858                     Huntington Disease       ISA
# ...                                    ...       ...
# 1739                          Hemophilia B       ISA
# 3661                               Obesity       ISA
# 6487         Hereditary Multiple Exostoses       ISA
# 1723                  Factor XI Deficiency       ISA
# 7022  Familial hypocalciuric hypercalcemia       ISA
#
#                            object  pmid_count   subject_semantic_type  \
# 921   Neurodegenerative Disorders        2136     Disease or Syndrome
# 3847           Metabolic Diseases        1243     Disease or Syndrome
# 2682          Hereditary Diseases         867     Disease or Syndrome
# 3448   Lysosomal Storage Diseases         573     Disease or Syndrome
# 858           Hereditary Diseases         322     Disease or Syndrome
# ...                           ...         ...                     ...
# 1739          Hereditary Diseases          26     Disease or Syndrome
# 3661                Overnutrition          26     Disease or Syndrome
# 6487          Hereditary Diseases          26  Congenital Abnormality
# 1723            Bleeding tendency          26     Disease or Syndrome
# 7022                Hypercalcemia          26     Disease or Syndrome
#
#      object_semantic_type
# 921   Disease or Syndrome
# 3847  Disease or Syndrome
# 2682  Disease or Syndrome
# 3448  Disease or Syndrome
# 858   Disease or Syndrome
# ...                   ...
# 1739  Disease or Syndrome
# 3661  Disease or Syndrome
# 6487  Disease or Syndrome
# 1723  Disease or Syndrome
# 7022  Disease or Syndrome
#
# [133 rows x 6 columns]
