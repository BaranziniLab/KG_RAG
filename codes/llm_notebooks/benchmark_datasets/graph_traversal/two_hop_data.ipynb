# %%
import pandas as pd
import os
from tqdm import tqdm
from dotenv import load_dotenv
from neo4j import GraphDatabase, basic_auth
import random

# %%
load_dotenv(os.path.join(os.path.expanduser('~'), '.neo4j_config.env'))
USER = os.environ.get('SPOKE_USER')
PSW = os.environ.get('SPOKE_PSW')
URI = os.environ.get('SPOKE_URI')

# %%
# %%time

DISEASE_QUERY = """
    MATCH(d:Disease)-[r:ASSOCIATES_DaG]->(g:Gene)
    RETURN DISTINCT d.identifier AS d_id, d.name AS d_name
"""

auth = basic_auth(USER, PSW)
sdb = GraphDatabase.driver(URI, auth=auth)

disease_list = []
with sdb.session() as session:
    with session.begin_transaction() as tx:
        result = tx.run(DISEASE_QUERY)
        for row in result:
            disease_list.append((row["d_id"], row["d_name"]))

disease_df = pd.DataFrame(disease_list, columns=["disease_id", "disease_name"])
disease_id_list = list(disease_df.disease_id.values)
# Out:
# CPU times: user 563 ms, sys: 79.5 ms, total: 643 ms
# Wall time: 15.6 s

# %%
def get_two_hop_data_step_1(central_node, predicate, disease_list, outbound=True):        
    if outbound:
        TWO_HOP_QUERY = """
            MATCH(d1:Disease)-[:{}]->(n:{})<-[:{}]-(d2:Disease)
            WHERE d1.identifier IN {} AND d2.identifier IN {} AND d1.name <> "malignant teratoma" AND d2.name <> "malignant teratoma"
            RETURN d1.name AS d1_name, n.name AS n_name, d2.name AS d2_name LIMIT 100
        """.format(predicate, central_node, predicate, disease_list, disease_list)
    else:
        TWO_HOP_QUERY = """
            MATCH(d1:Disease)<-[:{}]-(n:{})-[:{}]->(d2:Disease)
            WHERE d1.identifier IN {} AND d2.identifier IN {} AND d1.name <> "malignant teratoma" AND d2.name <> "malignant teratoma"
            RETURN d1.name AS d1_name, n.name AS n_name, d2.name AS d2_name LIMIT 100
        """.format(predicate, central_node, predicate, disease_list, disease_list)
    
    auth = basic_auth(USER, PSW)
    sdb = GraphDatabase.driver(URI, auth=auth)
    edge_list = []
    with sdb.session() as session:
        with session.begin_transaction() as tx:
            result = tx.run(TWO_HOP_QUERY)
            for row in result:
                edge_list.append((row["d1_name"], row["n_name"], row["d2_name"]))
    return pd.DataFrame(edge_list, columns=["node_1", "node_2", "node_3"])


def run_cypher(QUERY, variable_name):
    auth = basic_auth(USER, PSW)
    sdb = GraphDatabase.driver(URI, auth=auth)
    result = []
    with sdb.session() as session:
        with session.begin_transaction() as tx:
            result = tx.run(QUERY)
            output = []
            for row in result:
                output.append(row[variable_name])
    return output

# %%
def get_two_hop_data(central_node, predicate, disease_list, outbound=True):        
    if outbound:
        if central_node == "Gene":
            TWO_HOP_QUERY = """
                MATCH(d1:Disease)-[r1:{}]->(n:{})<-[r2:{}]-(d2:Disease)
                WHERE r1.diseases_sources <> ["textmining"] 
                AND r2.diseases_sources <> ["textmining"]
                AND d1.identifier IN {} AND d2.identifier IN {}
                RETURN DISTINCT d1.name AS d1_name, n.name AS n_name, d2.name AS d2_name
            """.format(predicate, central_node, predicate, disease_list, disease_list)
        else:
                TWO_HOP_QUERY = """
                MATCH(d1:Disease)-[r1:{}]->(n:{})<-[r2:{}]-(d2:Disease)
                WHERE d1.identifier IN {} AND d2.identifier IN {}
                RETURN DISTINCT d1.name AS d1_name, n.name AS n_name, d2.name AS d2_name
            """.format(predicate, central_node, predicate, disease_list, disease_list)            
    else:
        TWO_HOP_QUERY = """
            MATCH(d1:Disease)<-[r1:{}]-(n:{})-[r2:{}]->(d2:Disease)
            WHERE r1.diseases_sources <> ["textmining"] 
            AND r2.diseases_sources <> ["textmining"]
            AND d1.identifier IN {} AND d2.identifier IN {}
            RETURN DISTINCT d1.name AS d1_name, n.name AS n_name, d2.name AS d2_name
        """.format(predicate, central_node, predicate, disease_list, disease_list)
    auth = basic_auth(USER, PSW)
    sdb = GraphDatabase.driver(URI, auth=auth)
    edge_list = []
    with sdb.session() as session:
        with session.begin_transaction() as tx:
            result = tx.run(TWO_HOP_QUERY)
            for row in result:
                edge_list.append((row["d1_name"], row["n_name"], row["d2_name"]))
    sdb.close()
    return pd.DataFrame(edge_list, columns=["node_1", "node_2", "node_3"])


def get_all_two_hop_data(central_node, predicate, node1, node2, disease_list, outbound=True):
    if outbound:
        if central_node == "Gene":
            TWO_HOP_QUERY = """
                MATCH(d1:Disease)-[r1:{}]->(n:{})<-[r2:{}]-(d2:Disease)
                WHERE r1.diseases_sources <> ["textmining"]
                AND r2.diseases_sources <> ["textmining"]
                AND d1.name = "{}" AND d2.name = "{}"
                AND d1.identifier IN {} AND d2.identifier IN {}
                RETURN DISTINCT n.name AS n_name
            """.format(predicate, central_node, predicate, node1, node2, disease_list, disease_list)
        else:
            TWO_HOP_QUERY = """
                MATCH(d1:Disease)-[r1:{}]->(n:{})<-[r2:{}]-(d2:Disease)
                WHERE d1.name = "{}" AND d2.name = "{}"
                AND d1.identifier IN {} AND d2.identifier IN {}
                RETURN DISTINCT n.name AS n_name
            """.format(predicate, central_node, predicate, node1, node2, disease_list, disease_list)
    else:
        TWO_HOP_QUERY = """
        MATCH(d1:Disease)<-[r1:{}]-(n:{})-[r2:{}]->(d2:Disease)
        WHERE d1.name = "{}" AND d2.name = "{}"
        AND d1.identifier IN {} AND d2.identifier IN {}
        RETURN DISTINCT n.name AS n_name
    """.format(predicate, central_node, predicate, node1, node2, disease_list, disease_list)
    auth = basic_auth(USER, PSW)
    sdb = GraphDatabase.driver(URI, auth=auth)
    central_node_list = []
    with sdb.session() as session:
        with session.begin_transaction() as tx:
            result = tx.run(TWO_HOP_QUERY)
            for row in result:
                central_node_list.append(row["n_name"])
    sdb.close()
    return central_node_list

# %%
# %%time

# sample_diseases = random.sample(disease_id_list, 300)
# disease_gene_2_hop = get_two_hop_data("Gene", "ASSOCIATES_DaG", sample_diseases, outbound=True)
# disease_gene_2_hop = disease_gene_2_hop.sample(n=30)

# disease_gene_2_hop_with_all_central_nodes = []
# for index, row in disease_gene_2_hop.iterrows():
#     central_node_list = get_all_two_hop_data("Gene", "ASSOCIATES_DaG", row["node_1"], row["node_3"], sample_diseases)
#     disease_gene_2_hop_with_all_central_nodes.append((row["node_1"], row["node_3"], central_node_list))

# disease_gene_2_hop_with_all_central_nodes_df = pd.DataFrame(disease_gene_2_hop_with_all_central_nodes, columns=["disease_1", "disease_2", "central_nodes"])

# disease_gene_2_hop_with_all_central_nodes_df.loc[:, "text"] = "What are the Genes that are commonly associated with both " + disease_gene_2_hop_with_all_central_nodes_df.disease_1 + " and " + disease_gene_2_hop_with_all_central_nodes_df.disease_2 + "?"
# Out:
# CPU times: user 886 ms, sys: 122 ms, total: 1.01 s
# Wall time: 7.91 s

# %%
# %%time

sample_diseases = random.sample(disease_id_list, 300)
disease_symptom_2_hop = get_two_hop_data("Symptom", "PRESENTS_DpS", sample_diseases, outbound=True)
disease_symptom_2_hop = disease_symptom_2_hop.sample(n=30)

disease_symptom_2_hop_with_all_central_nodes = []
for index, row in disease_symptom_2_hop.iterrows():
    central_node_list = get_all_two_hop_data("Symptom", "PRESENTS_DpS", row["node_1"], row["node_3"], sample_diseases, outbound=True)
    disease_symptom_2_hop_with_all_central_nodes.append((row["node_1"], row["node_3"], central_node_list))

disease_symptom_2_hop_with_all_central_nodes_df = pd.DataFrame(disease_symptom_2_hop_with_all_central_nodes, columns=["disease_1", "disease_2", "central_nodes"])

disease_symptom_2_hop_with_all_central_nodes_df.loc[:, "text"] = "What are the Symptoms that are commonly associated with both " + disease_symptom_2_hop_with_all_central_nodes_df.disease_1 + " and " + disease_symptom_2_hop_with_all_central_nodes_df.disease_2 + "?"
# Out:
# CPU times: user 1.12 s, sys: 144 ms, total: 1.26 s
# Wall time: 8.21 s

# %%
# %%time

sample_diseases = random.sample(disease_id_list, 300)
disease_anatomy_2_hop = get_two_hop_data("Anatomy", "LOCALIZES_DlA", sample_diseases, outbound=True)
disease_anatomy_2_hop = disease_anatomy_2_hop.sample(n=30)

disease_anatomy_2_hop_with_all_central_nodes = []
for index, row in disease_anatomy_2_hop.iterrows():
    central_node_list = get_all_two_hop_data("Anatomy", "LOCALIZES_DlA", row["node_1"], row["node_3"], sample_diseases, outbound=True)
    disease_anatomy_2_hop_with_all_central_nodes.append((row["node_1"], row["node_3"], central_node_list))

disease_anatomy_2_hop_with_all_central_nodes_df = pd.DataFrame(disease_anatomy_2_hop_with_all_central_nodes, columns=["disease_1", "disease_2", "central_nodes"])

disease_anatomy_2_hop_with_all_central_nodes_df.loc[:, "text"] = "What are the Anatomy that are commonly associated with both " + disease_anatomy_2_hop_with_all_central_nodes_df.disease_1 + " and " + disease_anatomy_2_hop_with_all_central_nodes_df.disease_2 + "?"
# Out:
# CPU times: user 539 ms, sys: 72.1 ms, total: 611 ms
# Wall time: 6.6 s

# %%
disease_node_2_hop_data = pd.concat([disease_gene_2_hop_with_all_central_nodes_df, disease_symptom_2_hop_with_all_central_nodes_df,disease_anatomy_2_hop_with_all_central_nodes_df], ignore_index=True)
disease_node_2_hop_data = disease_node_2_hop_data.sample(frac=1)
disease_node_2_hop_data.to_csv("../../../../data/benchmark_datasets/disease_two_hop_validation_data.csv", index=False, header=True)

# %%
disease_node_2_hop_data.text.values[10]
# Out:
# 'What are the Genes that are commonly associated with both disease of anatomical entity and nephrogenic diabetes insipidus?'

# %%
disease_node_2_hop_data.central_nodes.values[10]
# Out:
# ['AQP2', 'AVPR2']

# %%
disease_node_2_hop_data.head(50)
# Out:
#                                             disease_1  \
# 62                                      optic atrophy
# 60                                     tongue disease
# 79                              Dandy-Walker syndrome
# 58                                             goiter
# 66                                         insulinoma
# 20                       disease of anatomical entity
# 65                                      cholesteatoma
# 56                        Charcot-Marie-Tooth disease
# 78                                          exotropia
# 52                                  macrocytic anemia
# 11                       disease of anatomical entity
# 54                             hemochromatosis type 1
# 32                                immunodeficiency 53
# 77                    hypoplastic left heart syndrome
# 12                       disease of anatomical entity
# 49                                Stormorken syndrome
# 57               glutamate-cysteine ligase deficiency
# 80                                       fibrosarcoma
# 63                    well-differentiated liposarcoma
# 85                                 malignant teratoma
# 14                       disease of anatomical entity
# 39   combined oxidative phosphorylation deficiency 11
# 29                     musculoskeletal system disease
# 88                                    choanal atresia
# 10                                      lipodystrophy
# 37   combined oxidative phosphorylation deficiency 11
# 36                                     Lynch syndrome
# 35                                      MASA syndrome
# 30                                   Kniest dysplasia
# 18                       disease of anatomical entity
# 73  Hodgkin's lymphoma, lymphocytic-histiocytic pr...
# 47                         Cornelia de Lange syndrome
# 38  sensory ataxic neuropathy, dysarthria, and oph...
# 76   visual impairment and progressive phthisis bulbi
# 21                       disease of anatomical entity
# 71                           sebaceous adenocarcinoma
# 5                        disease of anatomical entity
# 3             paramyotonia congenita of Von Eulenburg
# 19                       disease of anatomical entity
# 83                      leukocyte adhesion deficiency
# 70                                 malignant teratoma
# 17                       disease of anatomical entity
# 33                                 mevalonic aciduria
# 2                        disease of anatomical entity
# 8                      musculoskeletal system disease
# 51                                   Kniest dysplasia
# 82                               septooptic dysplasia
# 68                                degenerative myopia
# 16                     musculoskeletal system disease
# 6                        disease of anatomical entity
#
#                                             disease_2  \
# 62                            psammomatous meningioma
# 60                                   Crouzon syndrome
# 79                                      optic atrophy
# 58            Human papillomavirus infectious disease
# 66                    congenital diaphragmatic hernia
# 20                 primary hypoalphalipoproteinemia 1
# 65                     adamantinous craniopharyngioma
# 56                               alcohol use disorder
# 78                                   Crouzon syndrome
# 52                            colonic benign neoplasm
# 11                     nephrogenic diabetes insipidus
# 54                     primary sclerosing cholangitis
# 32       adenine phosphoribosyltransferase deficiency
# 77                               Takayasu's arteritis
# 12                     musculoskeletal system disease
# 49  mitochondrial complex III deficiency nuclear t...
# 57                    mucopolysaccharidosis type IIID
# 80                           congenital heart disease
# 63                             restless legs syndrome
# 85                            psammomatous meningioma
# 14                     musculoskeletal system disease
# 39      developmental and epileptic encephalopathy 73
# 29                           bone development disease
# 88                                       fibrosarcoma
# 10                        Charcot-Marie-Tooth disease
# 37                         Ellis-Van Creveld syndrome
# 36                          Tonne-Kalscheuer syndrome
# 35               hereditary sensory neuropathy type 4
# 30                       glycogen storage disease IXd
# 18                                      lipodystrophy
# 73                                     dacryocystitis
# 47                               tuberous sclerosis 2
# 38    combined oxidative phosphorylation deficiency 1
# 76                                      optic atrophy
# 21                     musculoskeletal system disease
# 71                                  testicular cancer
# 5                            bone development disease
# 3                      musculoskeletal system disease
# 19                     musculoskeletal system disease
# 83                                       colon cancer
# 70                                      optic atrophy
# 17                     musculoskeletal system disease
# 33                                  Noonan syndrome 1
# 2                      musculoskeletal system disease
# 8                        disease of anatomical entity
# 51                     osteogenesis imperfecta type 1
# 82                                  lateral sclerosis
# 68                                   refractive error
# 16                       disease of anatomical entity
# 6                      musculoskeletal system disease
#
#                                         central_nodes  \
# 62  [arachnoid mater, internal carotid artery, sph...
# 60  [mandible, foramen magnum, lower jaw region, f...
# 79                           [skull, arachnoid mater]
# 58              [Voice Disorders, Respiratory Sounds]
# 66                                    [gastric juice]
# 20                                     [APOA1, ABCA1]
# 65  [cerebellopontine angle, sella turcica, orbit ...
# 56  [Aging, Premature, Tremor, Auditory Perceptual...
# 78                [orbit of skull, oculomotor muscle]
# 52                              [Diarrhea, Confusion]
# 11                                      [AQP2, AVPR2]
# 54  [Abdominal Pain, Ascites, Abnormality of the s...
# 32          [Abnormality of the genitourinary system]
# 77  [aortic valve, brachiocephalic artery, ductus ...
# 12  [STAT3, TLR7, IL17A, SVIL, LFNG, TRAPPC2, TBX6...
# 49  [Abnormality of the eye, Abnormality of the ca...
# 57  [Abnormality of the cardiovascular system, Ref...
# 80                           [embryo, cardiac atrium]
# 63  [appendage, forelimb stylopod, hindlimb zeugop...
# 85  [middle cranial fossa, pineal body, third vent...
# 14  [STAT3, TLR7, IL17A, SVIL, LFNG, TRAPPC2, TBX6...
# 39  [Seizure, Behavioral abnormality, Abnormal cer...
# 29  [CYP27B1, MAP3K7, CCDC134, TAB2, KDELR2, VDR, ...
# 88            [larynx, maxillary sinus, nasal cavity]
# 10                                      [BSCL2, LMNA]
# 37  [Abnormality of the cardiovascular system, Abn...
# 36  [Abnormality of movement, Speech Disorders, In...
# 35                                       [Paraplegia]
# 30          [Abnormality of the genitourinary system]
# 18  [AKT2, ADRA2A, CIDEC, LIPE, PPARG, PLIN1, AGPA...
# 73                            [nose, lymphoid tissue]
# 47  [Intellectual Disability, Deafness, Hearing Lo...
# 38  [Abnormality of acid-base homeostasis, Reflex,...
# 76  [orbit of skull, central retinal artery, pupil...
# 21  [STAT3, TLR7, IL17A, SVIL, LFNG, TRAPPC2, TBX6...
# 71                                       [lymph node]
# 5   [CYP27B1, MAP3K7, CCDC134, TAB2, KDELR2, VDR, ...
# 3                                             [SCN4A]
# 19  [STAT3, TLR7, IL17A, SVIL, LFNG, TRAPPC2, TBX6...
# 83                [cardiovascular system endothelium]
# 70  [sella turcica, orbit of skull, septum pelluci...
# 17  [STAT3, TLR7, IL17A, SVIL, LFNG, TRAPPC2, TBX6...
# 33  [Weight Loss, Kyphosis, Thinness, Intellectual...
# 2   [STAT3, TLR7, IL17A, SVIL, LFNG, TRAPPC2, TBX6...
# 8   [IL17A, TLR7, IL1R1, SVIL, NLRP1, DNASE1L3, RI...
# 51  [Deafness, Hearing Loss, Conductive, Hearing L...
# 82                    [central nervous system, brain]
# 68  [sclera, corneal endothelium, substantia propr...
# 16  [IL17A, TLR7, IL1R1, SVIL, NLRP1, DNASE1L3, RI...
# 6   [STAT3, TLR7, IL17A, SVIL, LFNG, TRAPPC2, TBX6...
#
#                                                  text
# 62  What are the Anatomy that are commonly associa...
# 60  What are the Anatomy that are commonly associa...
# 79  What are the Anatomy that are commonly associa...
# 58  What are the Symptoms that are commonly associ...
# 66  What are the Anatomy that are commonly associa...
# 20  What are the Genes that are commonly associate...
# 65  What are the Anatomy that are commonly associa...
# 56  What are the Symptoms that are commonly associ...
# 78  What are the Anatomy that are commonly associa...
# 52  What are the Symptoms that are commonly associ...
# 11  What are the Genes that are commonly associate...
# 54  What are the Symptoms that are commonly associ...
# 32  What are the Symptoms that are commonly associ...
# 77  What are the Anatomy that are commonly associa...
# 12  What are the Genes that are commonly associate...
# 49  What are the Symptoms that are commonly associ...
# 57  What are the Symptoms that are commonly associ...
# 80  What are the Anatomy that are commonly associa...
# 63  What are the Anatomy that are commonly associa...
# 85  What are the Anatomy that are commonly associa...
# 14  What are the Genes that are commonly associate...
# 39  What are the Symptoms that are commonly associ...
# 29  What are the Genes that are commonly associate...
# 88  What are the Anatomy that are commonly associa...
# 10  What are the Genes that are commonly associate...
# 37  What are the Symptoms that are commonly associ...
# 36  What are the Symptoms that are commonly associ...
# 35  What are the Symptoms that are commonly associ...
# 30  What are the Symptoms that are commonly associ...
# 18  What are the Genes that are commonly associate...
# 73  What are the Anatomy that are commonly associa...
# 47  What are the Symptoms that are commonly associ...
# 38  What are the Symptoms that are commonly associ...
# 76  What are the Anatomy that are commonly associa...
# 21  What are the Genes that are commonly associate...
# 71  What are the Anatomy that are commonly associa...
# 5   What are the Genes that are commonly associate...
# 3   What are the Genes that are commonly associate...
# 19  What are the Genes that are commonly associate...
# 83  What are the Anatomy that are commonly associa...
# 70  What are the Anatomy that are commonly associa...
# 17  What are the Genes that are commonly associate...
# 33  What are the Symptoms that are commonly associ...
# 2   What are the Genes that are commonly associate...
# 8   What are the Genes that are commonly associate...
# 51  What are the Symptoms that are commonly associ...
# 82  What are the Anatomy that are commonly associa...
# 68  What are the Anatomy that are commonly associa...
# 16  What are the Genes that are commonly associate...
# 6   What are the Genes that are commonly associate...

# %%
disease_node_2_hop_data[disease_node_2_hop_data.disease_1 == "choanal atresia"]
# Out:
#           disease_1     disease_2                            central_nodes  \
# 88  choanal atresia  fibrosarcoma  [larynx, maxillary sinus, nasal cavity]
#
#                                                  text
# 88  What are the Anatomy that are commonly associa...

# %%
df = pd.read_csv("../../../../data/benchmark_datasets/disease_two_hop_validation_data.csv")

# %%
import ast

df.loc[:, "node_count"] = df.central_nodes.apply(lambda x:len(ast.literal_eval(x)))
df[df.node_count == 3].central_nodes.values
# Out:
# array(["['Aging, Premature', 'Tremor', 'Auditory Perceptual Disorders']",
#        "['larynx', 'maxillary sinus', 'nasal cavity']",
#        "['sella turcica', 'orbit of skull', 'septum pellucidum']",
#        "['Deafness', 'Hearing Loss, Conductive', 'Hearing Loss']",
#        "['Purpura, Thrombocytopenic', 'Edema', 'Purpura']",
#        "['Paraplegia', 'Paralysis', 'Quadriplegia']",
#        "['brain', 'central nervous system', 'entire myelin sheath']"],
#       dtype=object)

# %%
df = pd.read_csv("../../../../data/benchmark_datasets/disease_two_hop_validation_data.csv")
df.text.values[0]
# Out:
# 'What are the Anatomy that are commonly associated with both optic atrophy and psammomatous meningioma?'

# %%
df.shape
# Out:
# (90, 4)
