# %%
import requests
import pandas as pd
import sqlite3
from tqdm import tqdm
from math import ceil

# %%
DB_PATH = "../../../data/benchmark_datasets/disgenet/disgenet_2020.db"


API_URL = "https://biothings.ncats.io/semmeddb/query"

REFERENCE_PREDICATE = "TREATS"
RETURN_RESULT_COUNT = 1000
PMID_THRESH = 25

# %%
# %%time

conn = sqlite3.connect(DB_PATH)
c = conn.cursor()


table_name = "diseaseAttributes"
c.execute("SELECT * FROM {}".format(table_name))
rows = c.fetchall()
disease_df = pd.DataFrame(rows, columns=["diseaseNID", "diseaseId", "diseaseName", "type"])

table_name = "geneAttributes"
c.execute("SELECT * FROM {}".format(table_name))
rows = c.fetchall()
gene_df = pd.DataFrame(rows, columns=["geneNID", "geneId", "geneName", "geneDescription", "pLI", "DSI", "DPI"])


table_name = "geneDiseaseNetwork"
c.execute("SELECT * FROM {}".format(table_name))
rows = c.fetchall()
disease_gene_df = pd.DataFrame(rows, columns=["NID", "diseaseNID", "geneNID", "source", "association", "associationType", "sentence", "pmid", "score", "EL", "EI", "year"])
# Selecting association with maximum score
disease_gene_df_selected  = disease_gene_df[disease_gene_df.score == 1]
disease_gene_df_selected_1 = pd.merge(disease_gene_df_selected, disease_df, on="diseaseNID")
disease_gene_df_selected_2 = pd.merge(disease_gene_df_selected_1, gene_df, on="geneNID")
# Out:
# CPU times: user 9.27 s, sys: 444 ms, total: 9.71 s
# Wall time: 10.1 s

# %%
disease_ids = disease_gene_df_selected_2.diseaseId.unique()

# %%
# %%time

result_list = []
for sel_disease_id in tqdm(disease_ids):
    params = {}
    params["q"] = "object.umls:{}".format(sel_disease_id)
    params["size"] = RETURN_RESULT_COUNT

    response = requests.get(API_URL, params=params)
    result = response.json()
    hits = result["hits"]
    for item in hits:
        if item["predicate"] == REFERENCE_PREDICATE:
            try:
                subject_semantic_type = item["subject"]["semantic_type_name"]  
                object_semantic_type = item["object"]["semantic_type_name"]  
            except:
                subject_semantic_type = None
            result_list.append((item["subject"]["name"], item["predicate"], item["object"]["name"], item["pmid_count"], subject_semantic_type, object_semantic_type))
# Out:
# 100%|█████████████████████████████████████████| 353/353 [04:01<00:00,  1.46it/s]
# CPU times: user 22.2 s, sys: 1.33 s, total: 23.5 s
# Wall time: 4min 1s

# %%
result_df = pd.DataFrame(result_list, columns=["subject", "predicate", "object", "pmid_count", "subject_semantic_type", "object_semantic_type"])
result_df
# Out:
#                                     subject predicate  \
# 0                       Replacement therapy    TREATS
# 1               Bone Marrow Transplantation    TREATS
# 2                        Genetic Counseling    TREATS
# 3      Cyclic AMP-Dependent Protein Kinases    TREATS
# 4                                 Miglustat    TREATS
# ...                                     ...       ...
# 10929                            Cladribine    TREATS
# 10930                Kidney Transplantation    TREATS
# 10931    Reconstructive Surgical Procedures    TREATS
# 10932                  Excision of mandible    TREATS
# 10933       Therapeutic radiology procedure    TREATS
#
#                           object  pmid_count  \
# 0               Sandhoff Disease           1
# 1               Sandhoff Disease           1
# 2               Sandhoff Disease           1
# 3               Sandhoff Disease           1
# 4               Sandhoff Disease           4
# ...                          ...         ...
# 10929  Infantile myofibromatosis           1
# 10930  Infantile myofibromatosis           1
# 10931  Infantile myofibromatosis           2
# 10932  Infantile myofibromatosis           1
# 10933  Infantile myofibromatosis           1
#
#                      subject_semantic_type object_semantic_type
# 0      Therapeutic or Preventive Procedure  Disease or Syndrome
# 1      Therapeutic or Preventive Procedure  Disease or Syndrome
# 2      Therapeutic or Preventive Procedure  Disease or Syndrome
# 3          Amino Acid, Peptide, or Protein  Disease or Syndrome
# 4                  Pharmacologic Substance  Disease or Syndrome
# ...                                    ...                  ...
# 10929              Pharmacologic Substance   Neoplastic Process
# 10930  Therapeutic or Preventive Procedure   Neoplastic Process
# 10931  Therapeutic or Preventive Procedure   Neoplastic Process
# 10932  Therapeutic or Preventive Procedure   Neoplastic Process
# 10933  Therapeutic or Preventive Procedure   Neoplastic Process
#
# [10934 rows x 6 columns]

# %%
result_df = result_df.explode("subject_semantic_type")
result_df = result_df.explode("object_semantic_type")
result_df = result_df.explode("subject")
result_df = result_df.explode("object")
result_df.sort_values(by="pmid_count", ascending=False)
# Out:
#                                subject predicate  \
# 100                  Chemoembolization    TREATS
# 100                  Chemoembolisation    TREATS
# 6664                        inhibitors    TREATS
# 359      Operative Surgical Procedures    TREATS
# 359      Operative Surgical Procedures    TREATS
# ...                                ...       ...
# 4653                           Alkynes    TREATS
# 4652                Transanal Excision    TREATS
# 4651                 tyrosine receptor    TREATS
# 4650            Pancreaticojejunostomy    TREATS
# 10933  Therapeutic radiology procedure    TREATS
#
#                                          object  pmid_count  \
# 100                             Liver carcinoma        2408
# 100                             Liver carcinoma        2408
# 6664   Diabetes Mellitus, Non-Insulin-Dependent         948
# 359                                     sarcoma         508
# 359                                     Sarcoma         508
# ...                                         ...         ...
# 4653            Gastrointestinal Stromal Tumors           1
# 4652            Gastrointestinal Stromal Tumors           1
# 4651            Gastrointestinal Stromal Tumors           1
# 4650            Gastrointestinal Stromal Tumors           1
# 10933                 Infantile myofibromatosis           1
#
#                      subject_semantic_type object_semantic_type
# 100    Therapeutic or Preventive Procedure   Neoplastic Process
# 100    Therapeutic or Preventive Procedure   Neoplastic Process
# 6664          Chemical Viewed Functionally  Disease or Syndrome
# 359    Therapeutic or Preventive Procedure   Neoplastic Process
# 359    Therapeutic or Preventive Procedure   Neoplastic Process
# ...                                    ...                  ...
# 4653                      Organic Chemical   Neoplastic Process
# 4652   Therapeutic or Preventive Procedure   Neoplastic Process
# 4651       Amino Acid, Peptide, or Protein   Neoplastic Process
# 4650   Therapeutic or Preventive Procedure   Neoplastic Process
# 10933  Therapeutic or Preventive Procedure   Neoplastic Process
#
# [12070 rows x 6 columns]

# %%
result_df.subject_semantic_type.unique()
# Out:
# array(['Therapeutic or Preventive Procedure',
#        'Amino Acid, Peptide, or Protein', 'Pharmacologic Substance',
#        'Health Care Activity', 'Chemical Viewed Functionally',
#        'Gene or Genome', 'Hazardous or Poisonous Substance',
#        'Organic Chemical', 'Medical Device', 'Antibiotic', 'Hormone',
#        'Chemical Viewed Structurally',
#        'Nucleic Acid, Nucleoside, or Nucleotide', None,
#        'Biologically Active Substance', 'Clinical Drug',
#        'Inorganic Chemical', 'Research Activity',
#        'Daily or Recreational Activity',
#        'Indicator, Reagent, or Diagnostic Aid', 'Diagnostic Procedure',
#        'Vitamin', 'Immunologic Factor', 'Laboratory Procedure',
#        'Element, Ion, or Isotope'], dtype=object)

# %%
INCLUDE_SUBJECT_TYPE = [
    "Antibiotic", 
    "Pharmacologic Substance", 
    "Organic Chemical", 
    "Clinical Drug", 
    "Inorganic Chemical"
]

result_df = result_df[result_df.subject_semantic_type.isin(INCLUDE_SUBJECT_TYPE)].sort_values(by="pmid_count", ascending=False)
result_df.subject = result_df.subject.str.lower()
result_df.object = result_df.object.str.lower()
result_df = result_df.drop_duplicates(subset=["subject", "object"])

# %%
# PMID_THRESH = ceil(result_df.pmid_count.quantile(.95))

result_df_final_treats = result_df[result_df.pmid_count > PMID_THRESH]

result_df_final_treats.to_csv("../../../data/benchmark_datasets/semmeddb/compound_treats_disease_from_semmeddb.csv", index=False, header=True)

result_df_final_treats
# Out:
#                                 subject predicate  \
# 4023                            insulin    TREATS
# 1559                        factor viii    TREATS
# 2714                        antibiotics    TREATS
# 6658                 protease inhibitor    TREATS
# 6658                protease inhibitors    TREATS
# ...                                 ...       ...
# 117                radiopharmaceuticals    TREATS
# 7347                         nusinersen    TREATS
# 2598              macrolide antibiotics    TREATS
# 521                         gonadorelin    TREATS
# 367   protein-tyrosine kinase inhibitor    TREATS
#
#                                                  object  pmid_count  \
# 4023                                            obesity         429
# 1559                                       hemophilia a         389
# 2714                                    cystic fibrosis         341
# 6658           diabetes mellitus, non-insulin-dependent         335
# 6658           diabetes mellitus, non-insulin-dependent         335
# ...                                                 ...         ...
# 117                        malignant neoplasm of breast          27
# 7347  hmn (hereditary motor neuropathy) proximal type i          27
# 2598                                    cystic fibrosis          27
# 521            idiopathic hypogonadotropic hypogonadism          26
# 367                                             sarcoma          26
#
#         subject_semantic_type object_semantic_type
# 4023  Pharmacologic Substance  Disease or Syndrome
# 1559  Pharmacologic Substance  Disease or Syndrome
# 2714               Antibiotic  Disease or Syndrome
# 6658  Pharmacologic Substance  Disease or Syndrome
# 6658  Pharmacologic Substance  Disease or Syndrome
# ...                       ...                  ...
# 117   Pharmacologic Substance   Neoplastic Process
# 7347  Pharmacologic Substance  Disease or Syndrome
# 2598               Antibiotic  Disease or Syndrome
# 521   Pharmacologic Substance  Pathologic Function
# 367   Pharmacologic Substance   Neoplastic Process
#
# [81 rows x 6 columns]

# %%
result_df_final_treats.object_semantic_type.unique()
# Out:
# array(['Disease or Syndrome', 'Neoplastic Process', 'Finding',
#        'Pathologic Function'], dtype=object)
