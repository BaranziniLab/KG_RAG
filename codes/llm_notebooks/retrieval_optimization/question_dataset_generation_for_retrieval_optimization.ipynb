# %%
import pickle
import pandas as pd
import numpy as np
import random
from tqdm import tqdm
from sklearn.model_selection import train_test_split

# %%
def generate_questions(sel_disease, sel_predicate, questions_per_disease_per_predicate=10):
    sel_disease_id = diseases_selected[sel_disease]
    data_df_selected = data_df[(data_df.context.str.contains(sel_disease_id)) & (data_df.context.str.contains(sel_disease))]
    sel_index = data_df_selected.index.values[0]    
    data_edges = data[sel_index].split("\n")
    edges_selected = list(filter(None, (map(lambda x:x if " "+sel_predicate+" " in x else None, data_edges))))    
    questions_selected_ = list(map(lambda x:x.split(". Attr")[0], edges_selected))        
    predicate_list = []
    try:
        questions_selected = random.sample(questions_selected_, questions_per_disease_per_predicate)
    except:
        questions_selected = questions_selected_
    predicate_list = [sel_predicate]*len(questions_selected)
    questions_selected_transformed = list(map(lambda x:"".join([x.split(sel_predicate)[0], disease_predicates[sel_predicate], x.split(sel_predicate)[-1]]), questions_selected))
    return questions_selected_transformed, questions_selected, predicate_list

# %%
DATA_PATH = "../../../data/disease_context_from_dev.pickle"

QUESTIONS_PER_DISEASE_PER_PREDICATE = 15
VALIDATION_SIZE = 1000

# %%
with open(DATA_PATH, "rb") as f:
    data = pickle.load(f)

# %%
diseases_selected = {
    "lung cancer" : "DOID:1324",
    "breast cancer" : "DOID:1612",
    "prostate cancer" : "DOID:10283",
    "lymphoma" : "DOID:0060058",
    "pancreatic cancer" : "DOID:1793",
    "COVID-19" : "DOID:0080600",
    "hepatitis C" : "DOID:1883",
    "hepatitis B" : "DOID:2043",
    "pneumonia" : "DOID:552",
    "tuberculosis" : "DOID:399",
    "type 2 diabetes mellitus": "DOID:9352",
    "hypertension" : "DOID:10763",
    "Addison's disease" : "DOID:13774",
    "cardiac arrest" : "DOID:0060319",
    "renal fibrosis" : "DOID:0050855",
    "Huntington's disease" : "DOID:12858",
    "cystic fibrosis" : "DOID:1485",
    "sickle cell anemia" : "DOID:10923",
    "phenylketonuria" : "DOID:9281",
    "Tay-Sachs disease" : "DOID:3320",
    "scurvy" : "DOID:13724",
    "osteoporosis" : "DOID:11476",
    "rickets" : "DOID:10609",
    "anemia" : "DOID:2355",
    "riboflavin deficiency" : "DOID:8454"
}

# %%
disease_predicates = {
    "ISA" : "is a",
    "LOCALIZES" : "LOCALIZES".lower(), 
    "PRESENTS" : "PRESENTS".lower(),
    "RESEMBLES" : "RESEMBLES".lower(),
    "ASSOCIATES" : "ASSOCIATES".lower(),
    "TREATS" : "TREATS".lower(),
    "CONTRAINDICATES" : "CONTRAINDICATES".lower(),
    "CAUSES" : "CAUSES".lower(),
    "EXPRESSEDIN" : "is expressed in",
    "PREVALENCE" : "PREVALENCE".lower(),
    "INCREASEDIN" : "is increased in",
    "DECREASEDIN" : "is decreased in"
}

# %%
data_df = pd.DataFrame(data, columns=["context"])

# %%
# %%time

generated_questions_transformed = []
generated_questions = []
predicate_list = []
for sel_disease in tqdm(diseases_selected):
    for sel_predicate in disease_predicates:
        questions_selected_transformed, questions_selected, predicates = generate_questions(sel_disease, 
                                                                                            sel_predicate, 
                                                                                            questions_per_disease_per_predicate=QUESTIONS_PER_DISEASE_PER_PREDICATE
                                                                                        )
        generated_questions_transformed.extend(questions_selected_transformed)
        generated_questions.extend(questions_selected)
        predicate_list.extend(predicates)
# Out:
# 100%|███████████████████████████████████████████| 25/25 [01:24<00:00,  3.39s/it]
# CPU times: user 1min 24s, sys: 191 ms, total: 1min 24s
# Wall time: 1min 24s

# %%
generated_questions[25]
# Out:
# 'lung cancer ASSOCIATES Gene SNAI1'

# %%
from collections import Counter

count_dict = dict(Counter(predicate_list))
count_dict
# Out:
# {'ISA': 126,
#  'PRESENTS': 323,
#  'ASSOCIATES': 362,
#  'EXPRESSEDIN': 60,
#  'LOCALIZES': 317,
#  'RESEMBLES': 157,
#  'TREATS': 236,
#  'CONTRAINDICATES': 121,
#  'CAUSES': 19,
#  'INCREASEDIN': 15,
#  'DECREASEDIN': 1,
#  'PREVALENCE': 15}

# %%
# From the above count dictionary, it is evident that "DECREASEDIN" edge has only 1 count. Hence, removing that edge to obvisate issues while splitting the questions into validation and testing in a stratified fashion

generated_questions_df = pd.DataFrame(generated_questions, columns=["questions"])
generated_questions_df = generated_questions_df[~generated_questions_df.questions.str.contains("DECREASEDIN")]

generated_questions_transformed_df = pd.DataFrame(generated_questions_transformed, columns=["questions"])
generated_questions_transformed_df = generated_questions_transformed_df[~generated_questions_transformed_df.questions.str.contains("is decreased in")]

predicate_list_df = pd.DataFrame(predicate_list, columns=["predicates"])
predicate_list_df = predicate_list_df[predicate_list_df.predicates != "DECREASEDIN"]

generated_questions_transformed_df.loc[:, "questions_as_in_database"] = generated_questions_df["questions"]
generated_questions_transformed_df.loc[:, "predicate"] = predicate_list_df["predicates"]

# %%
generated_questions_transformed_df[generated_questions_transformed_df.questions.str.contains("lung cancer")]

# generated_questions_transformed_df
# Out:
#                                             questions  \
# 0       Disease main bronchus cancer is a lung cancer
# 1        Disease lung adenocarcinoma is a lung cancer
# 2         Disease pulmonary blastoma is a lung cancer
# 3   Disease epithelioid trophoblastic tumor is a l...
# 4             Disease Pancoast tumor is a lung cancer
# 5   Disease lung pleomorphic carcinoma is a lung c...
# 6   Disease pulmonary neuroendocrine tumor is a lu...
# 7               lung cancer is a Disease lung disease
# 8              Disease lung lymphoma is a lung cancer
# 9            Disease lung meningioma is a lung cancer
# 10         Disease lung hilum cancer is a lung cancer
# 11              Disease lung sarcoma is a lung cancer
# 12  lung cancer is a Disease respiratory system ca...
# 13            Disease lung carcinoma is a lung cancer
# 14  Disease adenosquamous lung carcinoma is a lung...
# 15   lung cancer presents Symptom Lung adenocarcinoma
# 16              lung cancer presents Symptom Neoplasm
# 17  lung cancer presents Symptom Neoplasm of the r...
# 18  lung cancer presents Symptom Neoplasm of the lung
# 19  lung cancer presents Symptom Alveolar cell car...
# 20  lung cancer presents Symptom Abnormal lung mor...
# 21  lung cancer presents Symptom Non-small cell lu...
# 22                   lung cancer associates Gene CD44
# 23                 Gene MIR372 associates lung cancer
# 24                Gene MIR4500 associates lung cancer
# 25                  lung cancer associates Gene SNAI1
# 26                 Gene MIR30B associates lung cancer
# 27                 Gene MIR504 associates lung cancer
# 28               Gene MIR129-2 associates lung cancer
# 29                 Gene MIR221 associates lung cancer
# 30               Gene MIRLET7C associates lung cancer
# 31               lung cancer associates Gene SLC22A18
# 32                   lung cancer associates Gene CD8A
# 33                Gene MIR4302 associates lung cancer
# 34                    lung cancer associates Gene IL2
# 35                 Gene MIR7-3 associates lung cancer
# 36                 Gene MIR10B associates lung cancer
# 37             Gene MMP10 is expressed in lung cancer
# 38              Gene CHIA is expressed in lung cancer
# 39              Gene FAT2 is expressed in lung cancer
# 40             Gene ANXA8 is expressed in lung cancer
# 41             Gene VSIG1 is expressed in lung cancer
# 42            Gene AKR1C1 is expressed in lung cancer
# 43             Gene LAMP3 is expressed in lung cancer
# 44           Gene SCGB3A1 is expressed in lung cancer
# 45             Gene NTRK2 is expressed in lung cancer
# 46            Gene ABCA13 is expressed in lung cancer
# 47            Gene UGT2A1 is expressed in lung cancer
# 48           Gene SPANXB1 is expressed in lung cancer
# 49              Gene IL37 is expressed in lung cancer
# 50         Gene TMPRSS11F is expressed in lung cancer
# 51          Gene C16orf89 is expressed in lung cancer
#
#                              questions_as_in_database    predicate
# 0        Disease main bronchus cancer ISA lung cancer          ISA
# 1         Disease lung adenocarcinoma ISA lung cancer          ISA
# 2          Disease pulmonary blastoma ISA lung cancer          ISA
# 3   Disease epithelioid trophoblastic tumor ISA lu...          ISA
# 4              Disease Pancoast tumor ISA lung cancer          ISA
# 5   Disease lung pleomorphic carcinoma ISA lung ca...          ISA
# 6   Disease pulmonary neuroendocrine tumor ISA lun...          ISA
# 7                lung cancer ISA Disease lung disease          ISA
# 8               Disease lung lymphoma ISA lung cancer          ISA
# 9             Disease lung meningioma ISA lung cancer          ISA
# 10          Disease lung hilum cancer ISA lung cancer          ISA
# 11               Disease lung sarcoma ISA lung cancer          ISA
# 12  lung cancer ISA Disease respiratory system cancer          ISA
# 13             Disease lung carcinoma ISA lung cancer          ISA
# 14  Disease adenosquamous lung carcinoma ISA lung ...          ISA
# 15   lung cancer PRESENTS Symptom Lung adenocarcinoma     PRESENTS
# 16              lung cancer PRESENTS Symptom Neoplasm     PRESENTS
# 17  lung cancer PRESENTS Symptom Neoplasm of the r...     PRESENTS
# 18  lung cancer PRESENTS Symptom Neoplasm of the lung     PRESENTS
# 19  lung cancer PRESENTS Symptom Alveolar cell car...     PRESENTS
# 20  lung cancer PRESENTS Symptom Abnormal lung mor...     PRESENTS
# 21  lung cancer PRESENTS Symptom Non-small cell lu...     PRESENTS
# 22                   lung cancer ASSOCIATES Gene CD44   ASSOCIATES
# 23                 Gene MIR372 ASSOCIATES lung cancer   ASSOCIATES
# 24                Gene MIR4500 ASSOCIATES lung cancer   ASSOCIATES
# 25                  lung cancer ASSOCIATES Gene SNAI1   ASSOCIATES
# 26                 Gene MIR30B ASSOCIATES lung cancer   ASSOCIATES
# 27                 Gene MIR504 ASSOCIATES lung cancer   ASSOCIATES
# 28               Gene MIR129-2 ASSOCIATES lung cancer   ASSOCIATES
# 29                 Gene MIR221 ASSOCIATES lung cancer   ASSOCIATES
# 30               Gene MIRLET7C ASSOCIATES lung cancer   ASSOCIATES
# 31               lung cancer ASSOCIATES Gene SLC22A18   ASSOCIATES
# 32                   lung cancer ASSOCIATES Gene CD8A   ASSOCIATES
# 33                Gene MIR4302 ASSOCIATES lung cancer   ASSOCIATES
# 34                    lung cancer ASSOCIATES Gene IL2   ASSOCIATES
# 35                 Gene MIR7-3 ASSOCIATES lung cancer   ASSOCIATES
# 36                 Gene MIR10B ASSOCIATES lung cancer   ASSOCIATES
# 37                 Gene MMP10 EXPRESSEDIN lung cancer  EXPRESSEDIN
# 38                  Gene CHIA EXPRESSEDIN lung cancer  EXPRESSEDIN
# 39                  Gene FAT2 EXPRESSEDIN lung cancer  EXPRESSEDIN
# 40                 Gene ANXA8 EXPRESSEDIN lung cancer  EXPRESSEDIN
# 41                 Gene VSIG1 EXPRESSEDIN lung cancer  EXPRESSEDIN
# 42                Gene AKR1C1 EXPRESSEDIN lung cancer  EXPRESSEDIN
# 43                 Gene LAMP3 EXPRESSEDIN lung cancer  EXPRESSEDIN
# 44               Gene SCGB3A1 EXPRESSEDIN lung cancer  EXPRESSEDIN
# 45                 Gene NTRK2 EXPRESSEDIN lung cancer  EXPRESSEDIN
# 46                Gene ABCA13 EXPRESSEDIN lung cancer  EXPRESSEDIN
# 47                Gene UGT2A1 EXPRESSEDIN lung cancer  EXPRESSEDIN
# 48               Gene SPANXB1 EXPRESSEDIN lung cancer  EXPRESSEDIN
# 49                  Gene IL37 EXPRESSEDIN lung cancer  EXPRESSEDIN
# 50             Gene TMPRSS11F EXPRESSEDIN lung cancer  EXPRESSEDIN
# 51              Gene C16orf89 EXPRESSEDIN lung cancer  EXPRESSEDIN

# %%
random_seed = 42
validation_questions, test_questions = train_test_split(generated_questions_transformed_df, 
                                                       test_size = len(generated_questions_df)-VALIDATION_SIZE, 
                                                       stratify = predicate_list_df.predicates.values,
                                                       random_state=random_seed)

# %%
validation_questions
# Out:
#                                               questions  \
# 345   pancreatic cancer localizes Anatomy common hep...
# 1035   cardiac arrest presents Symptom Hyperventilation
# 1633                 anemia localizes Anatomy colostrum
# 205        Compound Rosuvastatin treats prostate cancer
# 169        prostate cancer localizes Anatomy epithelium
# ...                                                 ...
# 446                 COVID-19 presents Symptom Halitosis
# 1116  Huntington's disease presents Symptom Apraxia,...
# 1145  Compound 3-(4-Amino-2-methyl-pyrimidin-5-ylmet...
# 774   type 2 diabetes mellitus localizes Anatomy ret...
# 470            Variant ﻿rs754119466 associates COVID-19
#
#                                questions_as_in_database   predicate
# 345   pancreatic cancer LOCALIZES Anatomy common hep...   LOCALIZES
# 1035   cardiac arrest PRESENTS Symptom Hyperventilation    PRESENTS
# 1633                 anemia LOCALIZES Anatomy colostrum   LOCALIZES
# 205        Compound Rosuvastatin TREATS prostate cancer      TREATS
# 169        prostate cancer LOCALIZES Anatomy epithelium   LOCALIZES
# ...                                                 ...         ...
# 446                 COVID-19 PRESENTS Symptom Halitosis    PRESENTS
# 1116  Huntington's disease PRESENTS Symptom Apraxia,...    PRESENTS
# 1145  Compound 3-(4-Amino-2-methyl-pyrimidin-5-ylmet...      TREATS
# 774   type 2 diabetes mellitus LOCALIZES Anatomy ret...   LOCALIZES
# 470            Variant ﻿rs754119466 ASSOCIATES COVID-19  ASSOCIATES
#
# [1000 rows x 3 columns]

# %%
validation_questions.to_csv("../data/validation_questions_for_retrieval_performance.csv", index=False, header=True)
test_questions.to_csv("../data/test_questions_for_retrieval_performance.csv", index=False, header=True)

# %%
sel_disease = "Addison's disease"
sel_predicate = "ASSOCIATES"

sel_disease_id = diseases_selected[sel_disease]
data_df_selected = data_df[(data_df.context.str.contains(sel_disease_id)) & (data_df.context.str.contains(sel_disease))]
data_df_selected

sel_index = data_df_selected.index.values[0]

data_edges = data[sel_index].split("\n")
edges_selected = list(filter(None, (map(lambda x:x if sel_predicate in x else None, data_edges))))

questions_selected = list(map(lambda x:x.split(". Attr")[0], edges_selected))

# random.sample(questions_selected, QUESTIONS_PER_DISEASE_PER_PREDICATE)

# %%
list(map(lambda x:"".join([x.split(sel_predicate)[0], sel_predicate.lower(), x.split(sel_predicate)[-1]]), questions_selected))
# Out:
# ["Addison's disease associates Gene NUDT10",
#  "Addison's disease associates Gene SCNN1G",
#  "Addison's disease associates Gene SCNN1A",
#  "Addison's disease associates Gene SERPINA6",
#  "Addison's disease associates Gene POMC",
#  "Addison's disease associates Gene AIRE",
#  "Addison's disease associates Gene CYP11B1",
#  "Addison's disease associates Gene SUFU",
#  "Addison's disease associates Gene CYP11B2",
#  "Addison's disease associates Gene GLI3",
#  "Addison's disease associates Gene TRAF7",
#  "Addison's disease associates Gene TERT",
#  "Addison's disease associates Gene PEX6",
#  "Addison's disease associates Gene CYP11A1",
#  "Addison's disease associates Gene PEX26",
#  "Addison's disease associates Gene PEX14",
#  "Addison's disease associates Gene PEX12",
#  "Addison's disease associates Gene PEX3",
#  "Addison's disease associates Gene TBX19",
#  "Addison's disease associates Gene PIK3CA",
#  "Addison's disease associates Gene PEX16",
#  "Addison's disease associates Gene CYP17A1",
#  "Addison's disease associates Gene NR3C1",
#  "Addison's disease associates Gene PCSK1",
#  "Addison's disease associates Gene PEX11B",
#  "Addison's disease associates Gene PDGFB",
#  "Addison's disease associates Gene SMARCE1",
#  "Addison's disease associates Gene TXNRD2",
#  "Addison's disease associates Gene BAP1",
#  "Addison's disease associates Gene PEX19",
#  "Addison's disease associates Gene HSD17B4",
#  "Addison's disease associates Gene PEX1",
#  "Addison's disease associates Gene NNT",
#  "Addison's disease associates Gene PEX5",
#  "Addison's disease associates Gene MC2R",
#  "Addison's disease associates Gene MRPS7",
#  "Addison's disease associates Gene HSD3B2",
#  "Addison's disease associates Gene AKT1",
#  "Addison's disease associates Gene HSD11B2",
#  "Addison's disease associates Gene GATC",
#  "Addison's disease associates Gene QRSL1",
#  "Addison's disease associates Gene SMO",
#  "Addison's disease associates Gene AAAS",
#  "Addison's disease associates Gene PEX13",
#  "Addison's disease associates Gene SCNN1B",
#  "Addison's disease associates Gene MRAP",
#  "Addison's disease associates Gene ABCD1",
#  "Addison's disease associates Gene SMARCB1",
#  "Addison's disease associates Gene KANSL1",
#  "Addison's disease associates Gene NFKB2",
#  "Addison's disease associates Gene GATB",
#  "Addison's disease associates Gene NR3C2",
#  "Addison's disease associates Gene STAR",
#  "Addison's disease associates Gene NR0B1",
#  "Addison's disease associates Gene TCTN3",
#  "Addison's disease associates Gene PEX10",
#  "Addison's disease associates Gene NF2",
#  "Addison's disease associates Gene PEX2",
#  "Addison's disease associates Gene POR",
#  "Variant rs128624225 associates Addison's disease"]

# %%
# Out:
# ['osteoporosis ISA Disease bone resorption disease. Attributes of this relationship are:',
#  'Disease idiopathic juvenile osteoporosis ISA osteoporosis. Attributes of this relationship are:',
#  'Disease glucocorticoid-induced osteoporosis ISA osteoporosis. Attributes of this relationship are:']
