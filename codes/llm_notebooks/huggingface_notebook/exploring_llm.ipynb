# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
import transformers
import torch

# %%
tokenizer = AutoTokenizer.from_pretrained("Yukang/Llama-2-13b-chat-longlora-32k-sft")
model = AutoModelForCausalLM.from_pretrained("Yukang/Llama-2-13b-chat-longlora-32k-sft")
# Out:
# ...
# ...
# ...
# Loading checkpoint shards:   0%|                          | 0/3 [00:00<?, ?it/s]

# %%
tokenizer = AutoTokenizer.from_pretrained(model)
pipeline = transformers.pipeline(
    "text-generation",
    model=model,
    torch_dtype=torch.float16,
    device_map="auto",
    token="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"
)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/anaconda3/envs/llm_env/lib/python3.10/site-packages/huggingface_hub/utils/_errors.py:261, in hf_raise_for_status(response, endpoint_name)
#     260 try:
# --> 261     response.raise_for_status()
#     262 except HTTPError as e:
#
# File ~/anaconda3/envs/llm_env/lib/python3.10/site-packages/requests/models.py:1021, in Response.raise_for_status(self)
#    1020 if http_error_msg:
# -> 1021     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 403 Client Error: Forbidden for url: https://huggingface.co/meta-llama/Llama-2-7b-chat-hf/resolve/main/tokenizer_config.json
#
# The above exception was the direct cause of the following exception:
#
# GatedRepoError                            Traceback (most recent call last)
# ...
